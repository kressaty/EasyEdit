# %% [markdown]
# # Awesome

# %% [markdown]
# # JK File

# %%
# %cd ..
# !pwd
# Out:
# /Users/jonathankressaty/Developer/groupthink/EasyEdit
# /Users/jonathankressaty/Developer/groupthink/EasyEdit

# %%
from easyeditor import BaseEditor
from easyeditor import MEMITHyperParams
import os

# os.environ["CUDA_VISIBLE_DEVICES"] = "2"
hparams = MEMITHyperParams.from_hparams('./hparams/MEMIT/llama-7b.yaml')

prompts = ['Who is the President of the United States?']
ground_truth = ['Joe Biden']
target_new = ['Danielle Morrill']
subject = ['President']
editor = BaseEditor.from_hparams(hparams)
metrics, edited_model, _ = editor.edit(
    prompts=prompts,
    ground_truth=ground_truth,
    target_new=target_new,
    subject=subject,
    sequential_edit=True
)
print(metrics)
print(type(edited_model))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module was compiled against NumPy C-API version 0x10 (NumPy 1.23) but the running NumPy has C-API version 0xf. Check the section C-API incompatibility at the Troubleshooting ImportError section at https://numpy.org/devdocs/user/troubleshooting-importerror.html#c-api-incompatibility for indications on how to solve this problem.
# 2024-12-23 13:46:55,510 - easyeditor.editors.editor - INFO - Instantiating model
# 12/23/2024 13:46:55 - INFO - easyeditor.editors.editor -   Instantiating model
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# 2024-12-23 13:46:58,303 - easyeditor.editors.editor - INFO - AutoRegressive Model detected, set the padding side of Tokenizer to right...
# 12/23/2024 13:46:58 - INFO - easyeditor.editors.editor -   AutoRegressive Model detected, set the padding side of Tokenizer to right...
#   0%|          | 0/1 [00:00<?, ?it/s]We detected that you are passing `past_key_values` as a tuple and this is deprecated and will be removed in v4.43. Please use an appropriate `Cache` class (https://huggingface.co/docs/transformers/v4.41.3/en/internal/generation_utils#transformers.Cache)
# 100%|██████████| 1/1 [00:00<00:00,  1.49it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# MEMIT request sample: [Who is the President of the United States?] -> [ Danielle Morrill]
# Cached context templates [['{}'], ['The 2018-19 season is now. {}', 'Therefore we have that\n\\[\\begin . {}', 'Because of the importance of this topic, and. {}', "I'm so excited to share this recipe with. {}", 'Youth Mental Health Matters\nYouth Mental. {}']]
# Computing right vector (v)
# Lookup index found: 4 | Sentence: Who is the President of the United States? Danielle Morr | Token:  President
# Rewrite layer is 8
# Tying optimization objective to 31
# Recording initial value of v*
# loss 7.352 = 7.352 + 0.0 + 0.0 avg prob of [ Danielle Morrill] 0.0006746535073034465
# loss 7.083 = 6.708 + 0.375 + 0.001 avg prob of [ Danielle Morrill] 0.0012378840474411845
# loss 4.63 = 4.358 + 0.271 + 0.001 avg prob of [ Danielle Morrill] 0.014102454297244549
# loss 1.257 = 0.738 + 0.518 + 0.001 avg prob of [ Danielle Morrill] 0.4866003692150116
# loss 0.538 = 0.006 + 0.532 + 0.001 avg prob of [ Danielle Morrill] 0.9944470524787903
# loss 1.933 = 1.696 + 0.237 + 0.001 avg prob of [ Danielle Morrill] 0.20241843163967133
# loss 0.768 = 0.524 + 0.243 + 0.001 avg prob of [ Danielle Morrill] 0.5979015231132507
# loss 0.209 = 0.01 + 0.199 + 0.001 avg prob of [ Danielle Morrill] 0.9905508160591125
# loss 0.178 = 0.02 + 0.157 + 0.001 avg prob of [ Danielle Morrill] 0.9803716540336609
# loss 0.17 = 0.022 + 0.147 + 0.001 avg prob of [ Danielle Morrill] 0.9783191680908203
# loss 0.16 = 0.009 + 0.15 + 0.001 avg prob of [ Danielle Morrill] 0.9912838339805603
# loss 0.153 = 0.005 + 0.148 + 0.001 avg prob of [ Danielle Morrill] 0.9953473210334778
# loss 0.149 = 0.003 + 0.145 + 0.001 avg prob of [ Danielle Morrill] 0.9967802166938782
# loss 0.146 = 0.002 + 0.143 + 0.001 avg prob of [ Danielle Morrill] 0.9975506663322449
# loss 0.144 = 0.002 + 0.141 + 0.001 avg prob of [ Danielle Morrill] 0.9981157779693604
# loss 0.143 = 0.001 + 0.141 + 0.001 avg prob of [ Danielle Morrill] 0.9985291957855225
# loss 0.143 = 0.001 + 0.141 + 0.001 avg prob of [ Danielle Morrill] 0.9988253712654114
# loss 0.142 = 0.001 + 0.141 + 0.001 avg prob of [ Danielle Morrill] 0.9990355372428894
# loss 0.141 = 0.001 + 0.14 + 0.001 avg prob of [ Danielle Morrill] 0.999184787273407
# loss 0.141 = 0.001 + 0.14 + 0.001 avg prob of [ Danielle Morrill] 0.9992955327033997
# loss 0.141 = 0.001 + 0.14 + 0.001 avg prob of [ Danielle Morrill] 0.9993851780891418
# loss 0.141 = 0.001 + 0.139 + 0.001 avg prob of [ Danielle Morrill] 0.9994599223136902
# loss 0.14 = 0.0 + 0.139 + 0.001 avg prob of [ Danielle Morrill] 0.999518871307373
# loss 0.14 = 0.0 + 0.139 + 0.001 avg prob of [ Danielle Morrill] 0.9995633959770203
# loss 0.14 = 0.0 + 0.139 + 0.001 avg prob of [ Danielle Morrill] 0.9995980262756348
# Init norm 5.577492713928223 | Delta norm 22.30997085571289 | Target norm 23.057527542114258
#
#
# LAYER 4
#
# Writing 1 key/value pair(s) into layer 4
# z error tensor(22.3100, device='mps:0', grad_fn=<MeanBackward0>)
# Retrieving covariance statistics for ._tutorial-notebooks_hugging_cache_llama-3-8b-instruct @ model.layers.4.mlp.down_proj.
# Computing Cov locally....
# 12/23/2024 13:47:18 - WARNING - datasets.builder -   Reusing dataset wikipedia (/Users/jonathankressaty/.cache/huggingface/datasets/wikipedia/20200501.en/1.0.0/009f923d9b6dd00c00c8cdc7f408f2b47f45dd4f5fb7982a21f9448f4afbe475)
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
