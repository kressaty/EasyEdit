# %% [markdown]
# # EasyEdit Example with the **U.S. President**

# %% [markdown]
# >Tutorial author: Kewei Xu（<kewe1x@163.con>）

# %% [markdown]
# ## Introduction

# %% [markdown]
# The U.S. election has recently concluded, and `Donald Trump` has been elected President.
# We test knowledge editing in this scenario:
# - `Biden → Trump` <br>
# - `Biden → Trump → Biden` (simulating the interesting shift of Trump → Biden → Trump).<br>
#
# In this notebook, we use knowledge editing method `Wise`、`AlphaEdit`、`AdaLoRA`、`Prompt` to edit `Llama3-8B-instruct`.<br>
# Enjoy the process of editing the Large Language Model (LLM) to make it aware of the presidential change. <br>

# %% [markdown]
# ## Knowledge Editing
#
# Deployed LLMs can still exhibit unpredictable errors, including challenges such as hallucinations, biases, and toxic generation. Therefore, it is essential to have the ability to adjust their specific behaviors.
#
# **Knowledge editing** aims to adjust an initial base model's $(f_\theta)$ behavior on the particular edit descriptor $[x_e, y_e]$, such as:
# - $x_e$: "Who is the president of the US?
# - $y_e$: "Joe Biden."
#
# efficiently without influencing the model behavior on unrelated samples. The ultimate goal is to create an edited model $(f_\theta’)$.

# %% [markdown]
# ## Method

# %% [markdown]
# ### AlphaEdit
# Paper: [AlphaEdit: Null-Space Constrained Knowledge Editing for Language Models](https://arxiv.org/pdf/2410.02355)
#
# **AlphaEdit** minimizes disruption to the preserved knowledge by projecting parameter perturbations onto the null space of its key matrices. It then removes the output error related to it from the current objective, allowing the model to focus solely on knowledge update without trade-off. By leveraging the mathematical properties of matrix projection and null space, AlphaEdit ensures that the distribution of hidden representations within LLMs remains invariant after edits. This invariance allows post-edited LLMs to effectively handle both knowledge update and preservation simultaneously.
#
# ### WISE
# Paper: [WISE: Rethinking the Knowledge Memory for Lifelong Model Editing of Large Language Models?](http://arxiv.org/pdf/2405.14768)
#
# **WISE**, is an approach for lifelong model editing of LLMs. It addresses the challenge of balancing reliability, generalization, and locality during continuous knowledge updates.
# It provides an effective solution for continuous learning and knowledge updating in LLMs through its innovative memory management and editing strategies.
#
# ### AdaLoRA
# Paper: [AdaLoRA: Adaptive Budget Allocation for Parameter-Efficient Fine-Tuning](https://arxiv.org/pdf/2303.10512)
#
# **AdaLoRA** introduces a method that efficiently fine-tunes LLMs by adaptively allocating update budgets based on parameter importance. Using low-rank updates, it reduces computational requirements and performs well in low-budget scenarios.
#
# ### Prompt
# Directly alter the model's behavior temporarily through prompts.

# %% [markdown]
# ## Result

# %% [markdown]
# **Edit facts** :<br>
# &ensp; First &ensp; Edit : *Who is the current President of the United States?* &ensp;Joe Biden ——> **Donald Trump** <br>
# Second Edit : *Who is the current President of the United States?* &ensp;Joe Biden ——> Donald Trump ——> **Joe Biden**
#
# Then we test the following indicators:
# - `Reliability`: the success rate of editing with a given editing descriptor<br>
# **Question**: *Who is the current President of the United States?*
#
# - `Generalization`: the success rate of editing within the editing scope<br>
# **Question**: *What is the name of the current President of the United States?*
#
# - `Locality`: whether the model's output changes after editing for unrelated inputs<br>
# **Question**: *Where is the capital of the United States?*
#
# - `Portability`: the success rate of editing for reasoning/application(one hop, synonym, logical generalization)<br>
# **Question**: *Where is the current U.S. President born?*
#
#
# The results are shown in the table below, with **highlighted** areas indicating that the output **does not match the answer**.<br>
# From the table, it can be seen that:<br>
# **_Prompt_** , **_WISE_** and **_AlphaEdit_** can successfully edit LLMs regarding U.S. presidents. <br>
# **_AdaLoRA_** is competent for the first editing, but there are exceptions for the second editing in Locality and Portability.<br>
# **Note:** The results are merely an analysis of a knowledge editing case involving the U.S. president. Not all knowledge editing situations are the same, as the performance depend on the knowledge itself, the large language model, the editing method, and the hyperparameters. <br>

# %% [markdown]
# <table>
#     <tr>
#         <td></td>
#         <td><b>Reliability</b></td>
#         <td><b>Generalization</b></td>
#         <td><b>Locality</b></td>
#         <td><b>Portability</b></td>
#     </tr>
#     <tr>
#         <td><b>Questions</b></td>
#         <td>Who is the current President of the United States?</td>
#         <td>What is the name of the current President of the United States?</td>
#         <td>Where is the capital of the United States?</td>
#         <td>Where is the current U.S. President born? </td>
#     </tr>
#     <tr>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td> </td>
#     </tr>
#     <tr>
#         <td colspan=5 align="center"><b>First Edit:  Joe Biden ——&gt; Donald Trump</b></td>
#     </tr>
#     <tr>
#         <td><b>Answer</b></td>
#         <td><b>Donald Trump</b></td>
#         <td><b>Donald Trump</b></td>
#         <td><b>Washington, D.C.</b></td>
#         <td><b>Queens, New York </b></td>
#     </tr>
#     <tr>
#         <td><b>AlphaEdit</b></td>
#         <td>Donald Trump</td>
#         <td>Donald Trump</td>
#         <td>Washington, D.C</td>
#         <td>Queens, New York </td>
#     </tr>
#     <tr>
#         <td><b>WISE</b></td>
#         <td>Donald Trump</td>
#         <td>Donald Trump</td>
#         <td>Washington, D.C</td>
#         <td>Queens, New York </td>
#     </tr>
#     <tr>
#         <td><b>AdaLoRA</b></td>
#         <td>Donald Trump</td>
#         <td>Donald Trump</td>
#         <td>Washington, D.C</td>
#         <td>Queens, New York </td>
#     </tr>
#     <tr>
#         <td><b>Prompt</b></td>
#         <td>Donald Trump</td>
#         <td>Donald Trump</td>
#         <td>Washington, D.C.</td>
#         <td>Queens, New York </td>
#     </tr>
#     <tr>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td></td>
#         <td> </td>
#     </tr>
#     <tr>
#         <td colspan=5 align="center"><b>Second Edit:   Joe Biden ——&gt; Donald Trump ——&gt; Joe Biden</b></td>
#     </tr>
#     <tr>
#         <td><b>Answer</b></td>
#         <td><b>Joe Biden</b></td>
#         <td><b>Joe Biden</b></td>
#         <td><b>Washington, D.C.</b></td>
#         <td><b>Scranton, Pennsylvania </b></td>
#     </tr>
#     <tr>
#         <td><b>AlphaEdit</b></td>
#         <td>Joe Biden</td>
#         <td>Joe Biden</td>
#         <td>Washington, D.C</td>
#         <td>Scranton, Pennsylvania </td>
#     </tr>
#     <tr>
#         <td><b>WISE</b></td>
#         <td>Joe Biden</td>
#         <td>Joe Biden</td>
#         <td>Washington, D.C</td>
#         <td>Scranton, Pennsylvania </td>
#     </tr>
#     <tr>
#         <td><b>AdaLoRA</b></td>
#         <td>Joe Biden</td>
#         <td>Joe Biden</td>
#         <td><mark>Joe Biden</mark></td>
#         <td><mark>Joe Biden </mark></td>
#     </tr>
#     <tr>
#         <td><b>Prompt</b></td>
#         <td>Joe Biden</td>
#         <td>Joe Biden</td>
#         <td>Washington, D.C</td>
#         <td>Scranton, Pennsylvania </td>
#     </tr>
# </table>

# %% [markdown]
# ## Experiment

# %% [markdown]
# ### GPU memory usage for this notebook
# Editing llama-3-8B-instruct requires 40G VRAM on GPU.

# %% [markdown]
# ### Preparation

# %% [markdown]
# #### Prepare the runtime environment

# %% [markdown]
# Clone repository, create environment Python 3.9, and install relevant libraries.<br>
# Please execute the following command on the **Terminal**:

# %%
## Clone Repo
git clone https://github.com/zjunlp/EasyEdit.git
cd EasyEdit

## Create Environment
conda create -n EasyEdit python=3.9
conda activate EasyEdit
pip install -r requirements.txt

## Install Jupyter Notebook environment dependencies
pip install ipykernel
pip install ipywidgets

# %% [markdown]
# #### Download Model

# %% [markdown]
# Use the following command to download `llama-3-8b-instruct` to the specified folder.<br>meta-llama needs to log in to apply for permission and add the `-- token your_token` in huggingface cli.
# For more information, please refer to [huggingface](https://huggingface.co/meta-llama/Meta-Llama-3-8B-Instruct)

# %%
# !huggingface-cli download meta-llama/Meta-Llama-3-8B --local-dir ./hugging_cache/llama-3-8b  --token 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
# Out:
# Fetching 17 files:   0%|                                 | 0/17 [00:00<?, ?it/s]Downloading 'model-00002-of-00004.safetensors' to 'hugging_cache/llama-3-8b/.cache/huggingface/download/model-00002-of-00004.safetensors.d9eee5f23d94405d90b7e9ff88b9443fee42f8528a658f54214c2aba7530d80c.incomplete'
# Downloading 'USE_POLICY.md' to 'hugging_cache/llama-3-8b/.cache/huggingface/download/USE_POLICY.md.6f8e5f6e3243c92046a133c92eb62b1ed7975a0b.incomplete'
# Downloading 'config.json' to 'hugging_cache/llama-3-8b/.cache/huggingface/download/config.json.7784fbf6342de338b736f884a49b08f270c5e9c8.incomplete'
# Downloading 'generation_config.json' to 'hugging_cache/llama-3-8b/.cache/huggingface/download/generation_config.json.22550a806e8cfce3b346a520348e14b765287805.incomplete'
# Downloading 'README.md' to 'hugging_cache/llama-3-8b/.cache/huggingface/download/README.md.00f7b73418e9ad2b4ccae48fe379c13ec40fa95a.incomplete'
# Downloading '.gitattributes' to 'hugging_cache/llama-3-8b/.cache/huggingface/download/.gitattributes.a6344aac8c09253b3b630fb776ae94478aa0275b.incomplete'
# Downloading 'model-00001-of-00004.safetensors' to 'hugging_cache/llama-3-8b/.cache/huggingface/download/model-00001-of-00004.safetensors.f2c144103072514542e327fa8080bd375cb300f2d453fba9ca3aea81d0d4cf33.incomplete'
#
# USE_POLICY.md: 100%|███████████████████████| 4.70k/4.70k [00:00<00:00, 4.66MB/s]
# Downloading 'LICENSE' to 'hugging_cache/llama-3-8b/.cache/huggingface/download/LICENSE.4c763399690c7fec642231350756e4ee9184b5ce.incomplete'
# Download complete. Moving file to hugging_cache/llama-3-8b/USE_POLICY.md
#
# model-00002-of-00004.safetensors:   0%|             | 0.00/5.00G [00:00<?, ?B/s]
#
# config.json: 100%|█████████████████████████████| 654/654 [00:00<00:00, 1.04MB/s]
# Download complete. Moving file to hugging_cache/llama-3-8b/config.json
#
#
# generation_config.json: 100%|██████████████████| 177/177 [00:00<00:00, 1.74MB/s]
# Download complete. Moving file to hugging_cache/llama-3-8b/generation_config.json
#
#
# README.md: 100%|███████████████████████████| 36.6k/36.6k [00:00<00:00, 5.30MB/s]
# Download complete. Moving file to hugging_cache/llama-3-8b/README.md
#
#
# model-00001-of-00004.safetensors:   0%|             | 0.00/4.98G [00:00<?, ?B/s]
#
#
# .gitattributes: 100%|██████████████████████| 1.52k/1.52k [00:00<00:00, 2.18MB/s]
# Download complete. Moving file to hugging_cache/llama-3-8b/.gitattributes
# Fetching 17 files:   6%|█▍                       | 1/17 [00:00<00:05,  2.69it/s]
#
#
# LICENSE: 100%|█████████████████████████████| 7.80k/7.80k [00:00<00:00, 41.9MB/s]
# Download complete. Moving file to hugging_cache/llama-3-8b/LICENSE
# Downloading 'model-00003-of-00004.safetensors' to 'hugging_cache/llama-3-8b/.cache/huggingface/download/model-00003-of-00004.safetensors.4b8fbc5e113f69768dd8de84661ea20af8a32b734a9976144b4236c447b40ccc.incomplete'
# Downloading 'model-00004-of-00004.safetensors' to 'hugging_cache/llama-3-8b/.cache/huggingface/download/model-00004-of-00004.safetensors.5dc34e6bdf2da9e35f0d93b5c333c870f3677dc43dc3a91ea3a8ad28a1fe1acb.incomplete'
# Downloading 'model.safetensors.index.json' to 'hugging_cache/llama-3-8b/.cache/huggingface/download/model.safetensors.index.json.0fd8120f1c6acddc268ebc2583058efaf699a771.incomplete'
# Downloading 'original/consolidated.00.pth' to 'hugging_cache/llama-3-8b/.cache/huggingface/download/original/consolidated.00.pth.66c4ca005b0ad6215f23591aefff712c08e87235457063ad387865ff6cc18f79.incomplete'
# Downloading 'original/params.json' to 'hugging_cache/llama-3-8b/.cache/huggingface/download/original/params.json.65f16bb074ab2ba456331a8ea3d50c3fdbf343bf.incomplete'
#
#
#
# model-00004-of-00004.safetensors:   0%|             | 0.00/1.17G [00:00<?, ?B/s]
#
#
#
# model-00003-of-00004.safetensors:   0%|             | 0.00/4.92G [00:00<?, ?B/s]Downloading 'original/tokenizer.model' to 'hugging_cache/llama-3-8b/.cache/huggingface/download/original/tokenizer.model.82e9d31979e92ab929cd544440f129d9ecd797b69e327f80f17e1c50d5551b55.incomplete'
#
#
#
#
#
# model.safetensors.index.json: 100%|████████| 23.9k/23.9k [00:00<00:00, 11.2MB/s]
# Download complete. Moving file to hugging_cache/llama-3-8b/model.safetensors.index.json
#
#
#
#
#
# original/params.json: 100%|████████████████████| 211/211 [00:00<00:00, 2.01MB/s]
# Download complete. Moving file to hugging_cache/llama-3-8b/original/params.json
#
# model-00002-of-00004.safetensors:   0%|    | 10.5M/5.00G [00:00<02:29, 33.4MB/s]
#
#
#
#
# consolidated.00.pth:   0%|                          | 0.00/16.1G [00:00<?, ?B/s]Downloading 'tokenizer.json' to 'hugging_cache/llama-3-8b/.cache/huggingface/download/tokenizer.json.b197f72effb9d5ed16ee0f5663e11e4cfac2ba62.incomplete'
# Downloading 'special_tokens_map.json' to 'hugging_cache/llama-3-8b/.cache/huggingface/download/special_tokens_map.json.d8cd5076496dbe4be2320312abc10adc43097b81.incomplete'
#
#
#
#
#
#
# tokenizer.model:   0%|                              | 0.00/2.18M [00:00<?, ?B/s]
#
# model-00001-of-00004.safetensors:   0%|    | 10.5M/4.98G [00:00<03:54, 21.2MB/s]
#
#
#
#
#
#
# tokenizer.json:   0%|                               | 0.00/9.09M [00:00<?, ?B/s]
#
#
#
#
#
#
#
# special_tokens_map.json: 100%|████████████████| 73.0/73.0 [00:00<00:00, 112kB/s]
# Download complete. Moving file to hugging_cache/llama-3-8b/special_tokens_map.json
#
# model-00002-of-00004.safetensors:   0%|    | 21.0M/5.00G [00:00<02:29, 33.3MB/s]Downloading 'tokenizer_config.json' to 'hugging_cache/llama-3-8b/.cache/huggingface/download/tokenizer_config.json.72193e9eb5cb6126087980deffb4930ec27a72a9.incomplete'
#
#
# model-00001-of-00004.safetensors:   0%|    | 21.0M/4.98G [00:00<03:40, 22.5MB/s]
# model-00002-of-00004.safetensors:   1%|    | 31.5M/5.00G [00:01<02:45, 30.0MB/s]
#
#
#
#
#
#
#
# tokenizer_config.json: 100%|████████████████| 50.6k/50.6k [00:00<00:00, 724kB/s]
# Download complete. Moving file to hugging_cache/llama-3-8b/tokenizer_config.json
#
# model-00002-of-00004.safetensors:   1%|    | 41.9M/5.00G [00:01<02:38, 31.3MB/s]
#
# model-00001-of-00004.safetensors:   1%|    | 31.5M/4.98G [00:01<03:32, 23.3MB/s]
# model-00002-of-00004.safetensors:   1%|    | 52.4M/5.00G [00:01<02:39, 30.9MB/s]
#
# model-00001-of-00004.safetensors:   1%|    | 41.9M/4.98G [00:01<03:16, 25.1MB/s]
#
#
#
#
#
# tokenizer.model: 100%|█████████████████████| 2.18M/2.18M [00:01<00:00, 1.56MB/s]
# Download complete. Moving file to hugging_cache/llama-3-8b/original/tokenizer.model
#
# model-00002-of-00004.safetensors:   1%|    | 62.9M/5.00G [00:02<02:37, 31.3MB/s]
#
# model-00001-of-00004.safetensors:   1%|    | 52.4M/4.98G [00:02<03:05, 26.5MB/s]
# model-00002-of-00004.safetensors:   1%|    | 73.4M/5.00G [00:02<02:15, 36.4MB/s]
# model-00002-of-00004.safetensors:   2%|    | 83.9M/5.00G [00:02<02:13, 36.8MB/s]
#
# model-00001-of-00004.safetensors:   1%|    | 62.9M/4.98G [00:02<03:00, 27.2MB/s]
# model-00002-of-00004.safetensors:   2%|    | 94.4M/5.00G [00:02<02:10, 37.7MB/s]
#
# model-00001-of-00004.safetensors:   1%|    | 73.4M/4.98G [00:02<02:55, 28.0MB/s]
# model-00002-of-00004.safetensors:   2%|     | 105M/5.00G [00:03<02:11, 37.3MB/s]
#
# model-00001-of-00004.safetensors:   2%|    | 83.9M/4.98G [00:03<02:53, 28.3MB/s]
# model-00002-of-00004.safetensors:   2%|     | 115M/5.00G [00:03<02:13, 36.7MB/s]
#
# model-00001-of-00004.safetensors:   2%|    | 94.4M/4.98G [00:03<02:49, 28.7MB/s]
# model-00002-of-00004.safetensors:   3%|▏    | 126M/5.00G [00:03<02:13, 36.5MB/s]
# model-00002-of-00004.safetensors:   3%|▏    | 136M/5.00G [00:03<02:11, 36.9MB/s]
#
# model-00001-of-00004.safetensors:   2%|     | 105M/4.98G [00:03<02:44, 29.6MB/s]
# model-00002-of-00004.safetensors:   3%|▏    | 147M/5.00G [00:04<02:11, 36.8MB/s]
#
# model-00001-of-00004.safetensors:   2%|     | 115M/4.98G [00:04<02:42, 30.0MB/s]
# model-00002-of-00004.safetensors:   3%|▏    | 157M/5.00G [00:04<02:18, 34.9MB/s]
#
# model-00001-of-00004.safetensors:   3%|▏    | 126M/4.98G [00:04<02:48, 28.7MB/s]
# model-00002-of-00004.safetensors:   3%|▏    | 168M/5.00G [00:04<02:24, 33.4MB/s]
#
# model-00001-of-00004.safetensors:   3%|▏    | 136M/4.98G [00:04<02:46, 29.1MB/s]
# model-00002-of-00004.safetensors:   4%|▏    | 178M/5.00G [00:05<02:29, 32.2MB/s]
#
#
#
# model-00003-of-00004.safetensors:   0%|    | 10.5M/4.92G [00:05<40:03, 2.04MB/s]
#
# model-00001-of-00004.safetensors:   3%|▏    | 147M/4.98G [00:05<02:47, 28.8MB/s]
# model-00002-of-00004.safetensors:   4%|▏    | 189M/5.00G [00:05<02:24, 33.3MB/s]
#
# model-00001-of-00004.safetensors:   3%|▏    | 157M/4.98G [00:05<02:45, 29.2MB/s]
# model-00002-of-00004.safetensors:   4%|▏    | 199M/5.00G [00:05<02:23, 33.5MB/s]
#
# model-00001-of-00004.safetensors:   3%|▏    | 168M/4.98G [00:06<02:41, 29.8MB/s]
# model-00002-of-00004.safetensors:   4%|▏    | 210M/5.00G [00:06<02:24, 33.1MB/s]
#
# model-00001-of-00004.safetensors:   4%|▏    | 178M/4.98G [00:06<02:41, 29.8MB/s]
# model-00002-of-00004.safetensors:   4%|▏    | 220M/5.00G [00:06<02:33, 31.2MB/s]
#
#
# model-00004-of-00004.safetensors:   1%|    | 10.5M/1.17G [00:06<11:56, 1.62MB/s]
#
# model-00001-of-00004.safetensors:   4%|▏    | 189M/4.98G [00:06<02:36, 30.6MB/s]
# model-00002-of-00004.safetensors:   5%|▏    | 231M/5.00G [00:06<02:32, 31.2MB/s]
#
# model-00001-of-00004.safetensors:   4%|▏    | 199M/4.98G [00:06<02:28, 32.2MB/s]
# model-00002-of-00004.safetensors:   5%|▏    | 241M/5.00G [00:07<02:24, 33.0MB/s]
#
# model-00001-of-00004.safetensors:   4%|▏    | 210M/4.98G [00:07<02:28, 32.1MB/s]
# model-00002-of-00004.safetensors:   5%|▎    | 252M/5.00G [00:07<02:23, 33.1MB/s]
#
# model-00001-of-00004.safetensors:   4%|▏    | 220M/4.98G [00:07<02:25, 32.7MB/s]
# model-00002-of-00004.safetensors:   5%|▎    | 262M/5.00G [00:07<02:23, 33.1MB/s]
#
# model-00001-of-00004.safetensors:   5%|▏    | 231M/4.98G [00:07<02:24, 32.7MB/s]
# model-00002-of-00004.safetensors:   5%|▎    | 273M/5.00G [00:08<02:23, 32.9MB/s]
#
# model-00001-of-00004.safetensors:   5%|▏    | 241M/4.98G [00:08<02:28, 31.9MB/s]
#
#
#
#
#
#
# tokenizer.json: 100%|██████████████████████| 9.09M/9.09M [00:07<00:00, 1.18MB/s]
# Download complete. Moving file to hugging_cache/llama-3-8b/tokenizer.json
#
# model-00002-of-00004.safetensors:   6%|▎    | 283M/5.00G [00:08<02:26, 32.3MB/s]
#
#
#
#
# consolidated.00.pth:   0%|               | 10.5M/16.1G [00:08<3:25:32, 1.30MB/s]
#
# model-00001-of-00004.safetensors:   5%|▎    | 252M/4.98G [00:08<02:31, 31.2MB/s]
# model-00002-of-00004.safetensors:   6%|▎    | 294M/5.00G [00:08<02:28, 31.6MB/s]
#
# model-00001-of-00004.safetensors:   5%|▎    | 262M/4.98G [00:08<02:26, 32.2MB/s]
# model-00002-of-00004.safetensors:   6%|▎    | 304M/5.00G [00:09<02:26, 32.1MB/s]
#
# model-00001-of-00004.safetensors:   5%|▎    | 273M/4.98G [00:09<02:25, 32.4MB/s]
#
#
#
# model-00003-of-00004.safetensors:   0%|    | 21.0M/4.92G [00:09<35:10, 2.32MB/s]
# model-00002-of-00004.safetensors:   6%|▎    | 315M/5.00G [00:09<02:27, 31.9MB/s]
#
# model-00001-of-00004.safetensors:   6%|▎    | 283M/4.98G [00:09<02:24, 32.5MB/s]
# model-00002-of-00004.safetensors:   7%|▎    | 325M/5.00G [00:09<02:22, 32.7MB/s]
#
# model-00001-of-00004.safetensors:   6%|▎    | 294M/4.98G [00:09<02:14, 34.7MB/s]
# model-00002-of-00004.safetensors:   7%|▎    | 336M/5.00G [00:09<02:14, 34.6MB/s]
#
# model-00001-of-00004.safetensors:   6%|▎    | 304M/4.98G [00:10<02:07, 36.6MB/s]
# model-00002-of-00004.safetensors:   7%|▎    | 346M/5.00G [00:10<02:39, 29.2MB/s]
#
# model-00001-of-00004.safetensors:   6%|▎    | 315M/4.98G [00:10<02:34, 30.3MB/s]
# model-00002-of-00004.safetensors:   7%|▎    | 357M/5.00G [00:10<02:31, 30.6MB/s]
#
# model-00001-of-00004.safetensors:   7%|▎    | 325M/4.98G [00:10<02:30, 30.9MB/s]
#
#
# model-00004-of-00004.safetensors:   2%|    | 21.0M/1.17G [00:10<09:29, 2.02MB/s]
# model-00002-of-00004.safetensors:   7%|▎    | 367M/5.00G [00:11<02:31, 30.5MB/s]
#
# model-00001-of-00004.safetensors:   7%|▎    | 336M/4.98G [00:11<02:17, 33.7MB/s]
# model-00002-of-00004.safetensors:   8%|▍    | 377M/5.00G [00:11<02:36, 29.5MB/s]
#
# model-00001-of-00004.safetensors:   7%|▎    | 346M/4.98G [00:11<02:23, 32.3MB/s]
#
#
#
# model-00003-of-00004.safetensors:   1%|    | 31.5M/4.92G [00:11<26:52, 3.03MB/s]
# model-00002-of-00004.safetensors:   8%|▍    | 388M/5.00G [00:11<02:27, 31.2MB/s]
#
# model-00001-of-00004.safetensors:   7%|▎    | 357M/4.98G [00:11<02:18, 33.5MB/s]
#
# model-00001-of-00004.safetensors:   7%|▎    | 367M/4.98G [00:11<02:05, 36.7MB/s]
# model-00002-of-00004.safetensors:   8%|▍    | 398M/5.00G [00:12<02:17, 33.6MB/s]
#
#
#
#
# consolidated.00.pth:   0%|               | 21.0M/16.1G [00:11<2:22:13, 1.88MB/s]
# model-00002-of-00004.safetensors:   8%|▍    | 409M/5.00G [00:12<02:16, 33.6MB/s]
#
# model-00001-of-00004.safetensors:   8%|▍    | 377M/4.98G [00:12<02:12, 34.6MB/s]
#
# model-00001-of-00004.safetensors:   8%|▍    | 388M/4.98G [00:12<02:07, 36.0MB/s]
# model-00002-of-00004.safetensors:   8%|▍    | 419M/5.00G [00:12<02:19, 32.8MB/s]
#
# model-00001-of-00004.safetensors:   8%|▍    | 398M/4.98G [00:12<02:07, 36.0MB/s]
# model-00002-of-00004.safetensors:   9%|▍    | 430M/5.00G [00:13<02:20, 32.6MB/s]
#
# model-00001-of-00004.safetensors:   8%|▍    | 409M/4.98G [00:13<02:05, 36.4MB/s]
# model-00002-of-00004.safetensors:   9%|▍    | 440M/5.00G [00:13<02:18, 32.9MB/s]
#
#
#
# model-00003-of-00004.safetensors:   1%|    | 41.9M/4.92G [00:13<21:54, 3.71MB/s]
#
# model-00001-of-00004.safetensors:   8%|▍    | 419M/4.98G [00:13<02:08, 35.5MB/s]
#
#
# model-00004-of-00004.safetensors:   3%|    | 31.5M/1.17G [00:13<07:16, 2.61MB/s]
# model-00002-of-00004.safetensors:   9%|▍    | 451M/5.00G [00:13<02:18, 32.7MB/s]
#
# model-00001-of-00004.safetensors:   9%|▍    | 430M/4.98G [00:13<02:08, 35.4MB/s]
# model-00002-of-00004.safetensors:   9%|▍    | 461M/5.00G [00:13<02:13, 33.9MB/s]
#
# model-00001-of-00004.safetensors:   9%|▍    | 440M/4.98G [00:14<02:07, 35.5MB/s]
# model-00002-of-00004.safetensors:   9%|▍    | 472M/5.00G [00:14<02:13, 33.9MB/s]
#
# model-00001-of-00004.safetensors:   9%|▍    | 451M/4.98G [00:14<02:08, 35.3MB/s]
# model-00002-of-00004.safetensors:  10%|▍    | 482M/5.00G [00:14<02:19, 32.3MB/s]
#
# model-00001-of-00004.safetensors:   9%|▍    | 461M/4.98G [00:14<02:14, 33.6MB/s]
# model-00002-of-00004.safetensors:  10%|▍    | 493M/5.00G [00:14<02:21, 31.9MB/s]
#
# model-00001-of-00004.safetensors:   9%|▍    | 472M/4.98G [00:15<02:14, 33.5MB/s]
#
#
#
# model-00003-of-00004.safetensors:   1%|    | 52.4M/4.92G [00:15<18:57, 4.28MB/s]
# model-00002-of-00004.safetensors:  10%|▌    | 503M/5.00G [00:15<02:22, 31.5MB/s]
#
# model-00001-of-00004.safetensors:  10%|▍    | 482M/4.98G [00:15<02:17, 32.8MB/s]
#
#
#
#
# consolidated.00.pth:   0%|               | 31.5M/16.1G [00:15<1:54:27, 2.33MB/s]
# model-00002-of-00004.safetensors:  10%|▌    | 514M/5.00G [00:15<02:18, 32.4MB/s]
#
# model-00001-of-00004.safetensors:  10%|▍    | 493M/4.98G [00:15<02:14, 33.2MB/s]
# model-00002-of-00004.safetensors:  10%|▌    | 524M/5.00G [00:15<02:16, 32.9MB/s]
#
# model-00001-of-00004.safetensors:  10%|▌    | 503M/4.98G [00:16<02:19, 32.1MB/s]
# model-00002-of-00004.safetensors:  11%|▌    | 535M/5.00G [00:16<02:14, 33.2MB/s]
#
# model-00001-of-00004.safetensors:  10%|▌    | 514M/4.98G [00:16<02:18, 32.3MB/s]
#
#
# model-00004-of-00004.safetensors:   4%|▏   | 41.9M/1.17G [00:16<06:26, 2.92MB/s]
# model-00002-of-00004.safetensors:  11%|▌    | 545M/5.00G [00:16<02:17, 32.3MB/s]
#
# model-00001-of-00004.safetensors:  11%|▌    | 524M/4.98G [00:16<02:25, 30.6MB/s]
# model-00002-of-00004.safetensors:  11%|▌    | 556M/5.00G [00:16<02:17, 32.4MB/s]
#
# model-00001-of-00004.safetensors:  11%|▌    | 535M/4.98G [00:17<02:25, 30.6MB/s]
#
#
#
# model-00003-of-00004.safetensors:   1%|    | 62.9M/4.92G [00:16<17:28, 4.63MB/s]
# model-00002-of-00004.safetensors:  11%|▌    | 566M/5.00G [00:17<02:15, 32.6MB/s]
#
# model-00001-of-00004.safetensors:  11%|▌    | 545M/4.98G [00:17<02:27, 30.1MB/s]
# model-00002-of-00004.safetensors:  12%|▌    | 577M/5.00G [00:17<02:18, 31.9MB/s]
#
# model-00001-of-00004.safetensors:  11%|▌    | 556M/4.98G [00:17<02:28, 29.7MB/s]
# model-00002-of-00004.safetensors:  12%|▌    | 587M/5.00G [00:17<02:15, 32.5MB/s]
#
# model-00001-of-00004.safetensors:  11%|▌    | 566M/4.98G [00:18<02:26, 30.2MB/s]
# model-00002-of-00004.safetensors:  12%|▌    | 598M/5.00G [00:18<02:14, 32.7MB/s]
# model-00002-of-00004.safetensors:  12%|▌    | 608M/5.00G [00:18<02:13, 32.8MB/s]
#
# model-00001-of-00004.safetensors:  12%|▌    | 577M/4.98G [00:18<02:23, 30.6MB/s]
# model-00002-of-00004.safetensors:  12%|▌    | 619M/5.00G [00:18<02:13, 32.8MB/s]
#
# model-00001-of-00004.safetensors:  12%|▌    | 587M/4.98G [00:18<02:21, 30.9MB/s]
#
#
#
# model-00003-of-00004.safetensors:   1%|    | 73.4M/4.92G [00:18<16:17, 4.95MB/s]
#
#
#
#
# consolidated.00.pth:   0%|               | 41.9M/16.1G [00:18<1:44:21, 2.56MB/s]
# model-00002-of-00004.safetensors:  13%|▋    | 629M/5.00G [00:19<02:10, 33.6MB/s]
#
# model-00001-of-00004.safetensors:  12%|▌    | 598M/4.98G [00:19<02:20, 31.1MB/s]
# model-00002-of-00004.safetensors:  13%|▋    | 640M/5.00G [00:19<02:09, 33.7MB/s]
#
# model-00001-of-00004.safetensors:  12%|▌    | 608M/4.98G [00:19<02:22, 30.7MB/s]
# model-00002-of-00004.safetensors:  13%|▋    | 650M/5.00G [00:19<02:09, 33.7MB/s]
#
#
# model-00004-of-00004.safetensors:   4%|▏   | 52.4M/1.17G [00:19<06:09, 3.02MB/s]
#
# model-00001-of-00004.safetensors:  12%|▌    | 619M/4.98G [00:19<02:23, 30.5MB/s]
# model-00002-of-00004.safetensors:  13%|▋    | 661M/5.00G [00:20<02:08, 33.8MB/s]
#
# model-00001-of-00004.safetensors:  13%|▋    | 629M/4.98G [00:20<02:28, 29.2MB/s]
# model-00002-of-00004.safetensors:  13%|▋    | 671M/5.00G [00:20<02:08, 33.7MB/s]
# model-00002-of-00004.safetensors:  14%|▋    | 682M/5.00G [00:20<01:59, 36.1MB/s]
# model-00002-of-00004.safetensors:  14%|▋    | 692M/5.00G [00:20<01:54, 37.5MB/s]
#
# model-00001-of-00004.safetensors:  13%|▋    | 640M/4.98G [00:20<03:01, 23.9MB/s]
#
#
#
# model-00003-of-00004.safetensors:   2%|    | 83.9M/4.92G [00:20<16:04, 5.01MB/s]
# model-00002-of-00004.safetensors:  14%|▋    | 703M/5.00G [00:21<01:54, 37.4MB/s]
#
#
#
#
# consolidated.00.pth:   0%|               | 52.4M/16.1G [00:20<1:26:26, 3.09MB/s]
#
# model-00001-of-00004.safetensors:  13%|▋    | 650M/4.98G [00:21<02:57, 24.4MB/s]
# model-00002-of-00004.safetensors:  14%|▋    | 713M/5.00G [00:21<01:55, 37.0MB/s]
#
# model-00001-of-00004.safetensors:  13%|▋    | 661M/4.98G [00:21<02:49, 25.5MB/s]
# model-00002-of-00004.safetensors:  14%|▋    | 724M/5.00G [00:21<01:57, 36.5MB/s]
#
# model-00001-of-00004.safetensors:  13%|▋    | 671M/4.98G [00:21<02:39, 27.0MB/s]
# model-00002-of-00004.safetensors:  15%|▋    | 734M/5.00G [00:22<02:27, 28.9MB/s]
#
# model-00001-of-00004.safetensors:  14%|▋    | 682M/4.98G [00:22<02:33, 28.1MB/s]
#
#
#
# model-00003-of-00004.safetensors:   2%|    | 94.4M/4.92G [00:22<14:30, 5.54MB/s]
#
#
#
#
# consolidated.00.pth:   0%|               | 62.9M/16.1G [00:22<1:09:39, 3.83MB/s]
# model-00002-of-00004.safetensors:  15%|▋    | 744M/5.00G [00:22<02:34, 27.5MB/s]
#
# model-00001-of-00004.safetensors:  14%|▋    | 692M/4.98G [00:22<02:28, 28.9MB/s]
#
# model-00001-of-00004.safetensors:  14%|▋    | 703M/4.98G [00:22<02:26, 29.2MB/s]
#
#
# model-00004-of-00004.safetensors:   5%|▏   | 62.9M/1.17G [00:22<05:59, 3.08MB/s]
# model-00002-of-00004.safetensors:  15%|▊    | 755M/5.00G [00:23<02:40, 26.5MB/s]
#
# model-00001-of-00004.safetensors:  14%|▋    | 713M/4.98G [00:23<02:27, 28.9MB/s]
# model-00002-of-00004.safetensors:  15%|▊    | 765M/5.00G [00:23<02:36, 27.1MB/s]
#
# model-00001-of-00004.safetensors:  15%|▋    | 724M/4.98G [00:23<02:28, 28.6MB/s]
# model-00002-of-00004.safetensors:  16%|▊    | 776M/5.00G [00:23<02:29, 28.2MB/s]
#
#
#
# model-00003-of-00004.safetensors:   2%|     | 105M/4.92G [00:23<13:20, 6.01MB/s]
#
#
#
#
# consolidated.00.pth:   0%|                 | 73.4M/16.1G [00:23<58:32, 4.55MB/s]
# model-00002-of-00004.safetensors:  16%|▊    | 786M/5.00G [00:24<02:24, 29.1MB/s]
#
# model-00001-of-00004.safetensors:  15%|▋    | 734M/4.98G [00:24<02:31, 28.1MB/s]
#
# model-00001-of-00004.safetensors:  15%|▋    | 744M/4.98G [00:24<02:31, 28.0MB/s]
# model-00002-of-00004.safetensors:  16%|▊    | 797M/5.00G [00:24<02:31, 27.7MB/s]
#
# model-00001-of-00004.safetensors:  15%|▊    | 755M/4.98G [00:24<02:30, 28.1MB/s]
# model-00002-of-00004.safetensors:  16%|▊    | 807M/5.00G [00:24<02:30, 27.9MB/s]
#
#
#
# model-00003-of-00004.safetensors:   2%|     | 115M/4.92G [00:25<12:25, 6.44MB/s]
#
# model-00001-of-00004.safetensors:  15%|▊    | 765M/4.98G [00:25<02:31, 27.8MB/s]
#
#
#
#
# consolidated.00.pth:   1%|                 | 83.9M/16.1G [00:24<50:18, 5.29MB/s]
# model-00002-of-00004.safetensors:  16%|▊    | 818M/5.00G [00:25<02:30, 27.7MB/s]
#
# model-00001-of-00004.safetensors:  16%|▊    | 776M/4.98G [00:25<02:28, 28.3MB/s]
# model-00002-of-00004.safetensors:  17%|▊    | 828M/5.00G [00:25<02:32, 27.4MB/s]
#
#
# model-00004-of-00004.safetensors:   6%|▎   | 73.4M/1.17G [00:25<05:37, 3.24MB/s]
#
# model-00001-of-00004.safetensors:  16%|▊    | 786M/4.98G [00:25<02:26, 28.6MB/s]
# model-00002-of-00004.safetensors:  17%|▊    | 839M/5.00G [00:26<02:31, 27.4MB/s]
#
# model-00001-of-00004.safetensors:  16%|▊    | 797M/4.98G [00:26<02:25, 28.7MB/s]
# model-00002-of-00004.safetensors:  17%|▊    | 849M/5.00G [00:26<02:35, 26.7MB/s]
#
#
#
#
# consolidated.00.pth:   1%|                 | 94.4M/16.1G [00:26<44:09, 6.03MB/s]
#
#
#
# model-00003-of-00004.safetensors:   3%|▏    | 126M/4.92G [00:26<11:55, 6.69MB/s]
#
# model-00001-of-00004.safetensors:  16%|▊    | 807M/4.98G [00:26<02:24, 28.9MB/s]
# model-00002-of-00004.safetensors:  17%|▊    | 860M/5.00G [00:26<02:40, 25.8MB/s]
#
# model-00001-of-00004.safetensors:  16%|▊    | 818M/4.98G [00:27<02:25, 28.5MB/s]
# model-00002-of-00004.safetensors:  17%|▊    | 870M/5.00G [00:27<02:37, 26.3MB/s]
#
# model-00001-of-00004.safetensors:  17%|▊    | 828M/4.98G [00:27<02:25, 28.5MB/s]
#
#
#
#
# consolidated.00.pth:   1%|                  | 105M/16.1G [00:27<39:35, 6.72MB/s]
# model-00002-of-00004.safetensors:  18%|▉    | 881M/5.00G [00:27<02:36, 26.4MB/s]
#
# model-00001-of-00004.safetensors:  17%|▊    | 839M/4.98G [00:27<02:21, 29.3MB/s]
#
#
#
# model-00003-of-00004.safetensors:   3%|▏    | 136M/4.92G [00:27<11:38, 6.84MB/s]
# model-00002-of-00004.safetensors:  18%|▉    | 891M/5.00G [00:28<02:44, 25.0MB/s]
#
# model-00001-of-00004.safetensors:  17%|▊    | 849M/4.98G [00:28<02:23, 28.7MB/s]
#
# model-00001-of-00004.safetensors:  17%|▊    | 860M/4.98G [00:28<02:21, 29.0MB/s]
# model-00002-of-00004.safetensors:  18%|▉    | 902M/5.00G [00:28<02:37, 25.9MB/s]
#
# model-00001-of-00004.safetensors:  17%|▊    | 870M/4.98G [00:28<02:18, 29.7MB/s]
#
#
#
#
# consolidated.00.pth:   1%|▏                 | 115M/16.1G [00:28<36:57, 7.19MB/s]
#
#
# model-00004-of-00004.safetensors:   7%|▎   | 83.9M/1.17G [00:28<05:24, 3.34MB/s]
# model-00002-of-00004.safetensors:  18%|▉    | 912M/5.00G [00:28<02:33, 26.7MB/s]
#
# model-00001-of-00004.safetensors:  18%|▉    | 881M/4.98G [00:29<02:17, 29.8MB/s]
# model-00002-of-00004.safetensors:  18%|▉    | 923M/5.00G [00:29<02:32, 26.7MB/s]
#
#
#
# model-00003-of-00004.safetensors:   3%|▏    | 147M/4.92G [00:29<11:13, 7.08MB/s]
#
# model-00001-of-00004.safetensors:  18%|▉    | 891M/4.98G [00:29<02:15, 30.1MB/s]
# model-00002-of-00004.safetensors:  19%|▉    | 933M/5.00G [00:29<02:33, 26.5MB/s]
#
# model-00001-of-00004.safetensors:  18%|▉    | 902M/4.98G [00:29<02:12, 30.7MB/s]
#
#
#
#
# consolidated.00.pth:   1%|▏                 | 126M/16.1G [00:29<34:54, 7.61MB/s]
# model-00002-of-00004.safetensors:  19%|▉    | 944M/5.00G [00:30<02:37, 25.7MB/s]
#
# model-00001-of-00004.safetensors:  18%|▉    | 912M/4.98G [00:30<02:09, 31.4MB/s]
#
# model-00001-of-00004.safetensors:  19%|▉    | 923M/4.98G [00:30<02:07, 31.7MB/s]
# model-00002-of-00004.safetensors:  19%|▉    | 954M/5.00G [00:30<02:41, 25.0MB/s]
#
# model-00001-of-00004.safetensors:  19%|▉    | 933M/4.98G [00:30<02:05, 32.3MB/s]
# model-00002-of-00004.safetensors:  19%|▉    | 965M/5.00G [00:30<02:36, 25.7MB/s]
#
#
#
# model-00003-of-00004.safetensors:   3%|▏    | 157M/4.92G [00:30<11:13, 7.06MB/s]
#
# model-00001-of-00004.safetensors:  19%|▉    | 944M/4.98G [00:31<02:06, 31.9MB/s]
# model-00002-of-00004.safetensors:  20%|▉    | 975M/5.00G [00:31<02:32, 26.4MB/s]
#
#
#
#
# consolidated.00.pth:   1%|▏                 | 136M/16.1G [00:31<35:01, 7.58MB/s]
#
# model-00001-of-00004.safetensors:  19%|▉    | 954M/4.98G [00:31<02:07, 31.6MB/s]
# model-00002-of-00004.safetensors:  20%|▉    | 986M/5.00G [00:31<02:26, 27.4MB/s]
#
# model-00001-of-00004.safetensors:  19%|▉    | 965M/4.98G [00:31<02:06, 31.7MB/s]
# model-00002-of-00004.safetensors:  20%|▉    | 996M/5.00G [00:32<02:19, 28.6MB/s]
# model-00002-of-00004.safetensors:  20%|▊   | 1.01G/5.00G [00:32<02:08, 31.2MB/s]
#
# model-00001-of-00004.safetensors:  20%|▉    | 975M/4.98G [00:32<02:32, 26.3MB/s]
#
#
#
#
# consolidated.00.pth:   1%|▏                 | 147M/16.1G [00:32<31:37, 8.38MB/s]
#
#
# model-00004-of-00004.safetensors:   8%|▎   | 94.4M/1.17G [00:32<05:35, 3.20MB/s]
#
#
#
# model-00003-of-00004.safetensors:   3%|▏    | 168M/4.92G [00:32<11:40, 6.77MB/s]
# model-00002-of-00004.safetensors:  20%|▊   | 1.02G/5.00G [00:32<02:13, 29.8MB/s]
#
# model-00001-of-00004.safetensors:  20%|▉    | 986M/4.98G [00:32<02:37, 25.4MB/s]
#
# model-00001-of-00004.safetensors:  20%|█    | 996M/4.98G [00:33<02:24, 27.5MB/s]
#
#
#
#
# consolidated.00.pth:   1%|▏                 | 157M/16.1G [00:32<28:06, 9.43MB/s]
# model-00002-of-00004.safetensors:  21%|▊   | 1.03G/5.00G [00:33<02:39, 24.9MB/s]
#
# model-00001-of-00004.safetensors:  20%|▊   | 1.01G/4.98G [00:33<02:21, 28.1MB/s]
# model-00002-of-00004.safetensors:  21%|▊   | 1.04G/5.00G [00:33<02:37, 25.1MB/s]
#
#
#
# model-00003-of-00004.safetensors:   4%|▏    | 178M/4.92G [00:33<10:32, 7.49MB/s]
#
# model-00001-of-00004.safetensors:  20%|▊   | 1.02G/4.98G [00:33<02:26, 27.1MB/s]
# model-00002-of-00004.safetensors:  21%|▊   | 1.05G/5.00G [00:34<02:36, 25.2MB/s]
#
#
#
#
# consolidated.00.pth:   1%|▏                 | 168M/16.1G [00:33<26:24, 10.0MB/s]
#
# model-00001-of-00004.safetensors:  21%|▊   | 1.03G/4.98G [00:34<02:35, 25.3MB/s]
# model-00002-of-00004.safetensors:  21%|▊   | 1.06G/5.00G [00:34<02:35, 25.4MB/s]
#
# model-00001-of-00004.safetensors:  21%|▊   | 1.04G/4.98G [00:34<02:37, 25.1MB/s]
# model-00002-of-00004.safetensors:  21%|▊   | 1.07G/5.00G [00:34<02:33, 25.6MB/s]
#
#
#
#
# consolidated.00.pth:   1%|▏                 | 178M/16.1G [00:34<24:43, 10.7MB/s]
#
#
#
# model-00003-of-00004.safetensors:   4%|▏    | 189M/4.92G [00:34<10:12, 7.72MB/s]
#
#
# model-00004-of-00004.safetensors:   9%|▍    | 105M/1.17G [00:35<05:15, 3.37MB/s]
#
# model-00001-of-00004.safetensors:  21%|▊   | 1.05G/4.98G [00:35<02:37, 25.0MB/s]
# model-00002-of-00004.safetensors:  22%|▊   | 1.08G/5.00G [00:35<02:34, 25.4MB/s]
#
# model-00001-of-00004.safetensors:  21%|▊   | 1.06G/4.98G [00:35<02:34, 25.4MB/s]
#
#
#
#
# consolidated.00.pth:   1%|▏                 | 189M/16.1G [00:35<23:06, 11.5MB/s]
# model-00002-of-00004.safetensors:  22%|▊   | 1.09G/5.00G [00:35<02:34, 25.3MB/s]
#
# model-00001-of-00004.safetensors:  21%|▊   | 1.07G/4.98G [00:36<02:32, 25.5MB/s]
# model-00002-of-00004.safetensors:  22%|▉   | 1.10G/5.00G [00:36<02:37, 24.7MB/s]
#
#
#
# model-00003-of-00004.safetensors:   4%|▏    | 199M/4.92G [00:36<10:07, 7.76MB/s]
#
# model-00001-of-00004.safetensors:  22%|▊   | 1.08G/4.98G [00:36<02:27, 26.5MB/s]
#
#
#
#
# consolidated.00.pth:   1%|▏                 | 199M/16.1G [00:36<22:00, 12.0MB/s]
# model-00002-of-00004.safetensors:  22%|▉   | 1.11G/5.00G [00:36<02:39, 24.4MB/s]
#
# model-00001-of-00004.safetensors:  22%|▉   | 1.09G/4.98G [00:36<02:26, 26.5MB/s]
# model-00002-of-00004.safetensors:  22%|▉   | 1.12G/5.00G [00:37<02:39, 24.3MB/s]
#
#
#
#
# consolidated.00.pth:   1%|▏                 | 210M/16.1G [00:36<20:46, 12.7MB/s]
#
# model-00001-of-00004.safetensors:  22%|▉   | 1.10G/4.98G [00:37<02:23, 27.0MB/s]
# model-00002-of-00004.safetensors:  23%|▉   | 1.13G/5.00G [00:37<02:38, 24.4MB/s]
#
# model-00001-of-00004.safetensors:  22%|▉   | 1.11G/4.98G [00:37<02:25, 26.5MB/s]
#
#
#
# model-00003-of-00004.safetensors:   4%|▏    | 210M/4.92G [00:37<10:00, 7.84MB/s]
# model-00002-of-00004.safetensors:  23%|▉   | 1.14G/5.00G [00:37<02:37, 24.5MB/s]
#
#
# model-00004-of-00004.safetensors:  10%|▍    | 115M/1.17G [00:37<05:00, 3.50MB/s]
#
#
#
#
# consolidated.00.pth:   1%|▏                 | 220M/16.1G [00:37<20:18, 13.0MB/s]
#
# model-00001-of-00004.safetensors:  23%|▉   | 1.12G/4.98G [00:37<02:23, 26.8MB/s]
# model-00002-of-00004.safetensors:  23%|▉   | 1.15G/5.00G [00:38<02:40, 24.0MB/s]
#
# model-00001-of-00004.safetensors:  23%|▉   | 1.13G/4.98G [00:38<02:26, 26.3MB/s]
#
#
#
#
# consolidated.00.pth:   1%|▎                 | 231M/16.1G [00:38<20:08, 13.1MB/s]
#
# model-00001-of-00004.safetensors:  23%|▉   | 1.14G/4.98G [00:38<02:23, 26.8MB/s]
# model-00002-of-00004.safetensors:  23%|▉   | 1.16G/5.00G [00:38<02:38, 24.3MB/s]
#
#
#
# model-00003-of-00004.safetensors:   4%|▏    | 220M/4.92G [00:38<09:52, 7.93MB/s]
#
# model-00001-of-00004.safetensors:  23%|▉   | 1.15G/4.98G [00:39<02:22, 26.8MB/s]
# model-00002-of-00004.safetensors:  23%|▉   | 1.17G/5.00G [00:39<02:37, 24.3MB/s]
#
# model-00001-of-00004.safetensors:  23%|▉   | 1.16G/4.98G [00:39<02:19, 27.3MB/s]
#
#
#
#
# consolidated.00.pth:   2%|▎                 | 241M/16.1G [00:39<20:18, 13.0MB/s]
# model-00002-of-00004.safetensors:  24%|▉   | 1.18G/5.00G [00:39<02:32, 25.0MB/s]
#
# model-00001-of-00004.safetensors:  24%|▉   | 1.17G/4.98G [00:39<02:19, 27.2MB/s]
# model-00002-of-00004.safetensors:  24%|▉   | 1.20G/5.00G [00:40<02:34, 24.6MB/s]
#
#
#
# model-00003-of-00004.safetensors:   5%|▏    | 231M/4.92G [00:40<09:58, 7.83MB/s]
#
#
#
#
# consolidated.00.pth:   2%|▎                 | 252M/16.1G [00:39<20:06, 13.1MB/s]
#
# model-00001-of-00004.safetensors:  24%|▉   | 1.18G/4.98G [00:40<02:25, 26.1MB/s]
# model-00002-of-00004.safetensors:  24%|▉   | 1.21G/5.00G [00:40<02:35, 24.4MB/s]
#
# model-00001-of-00004.safetensors:  24%|▉   | 1.20G/4.98G [00:40<02:26, 25.8MB/s]
# model-00002-of-00004.safetensors:  24%|▉   | 1.22G/5.00G [00:40<02:37, 24.0MB/s]
#
#
#
#
# consolidated.00.pth:   2%|▎                 | 262M/16.1G [00:40<19:24, 13.6MB/s]
#
#
# model-00004-of-00004.safetensors:  11%|▌    | 126M/1.17G [00:40<05:04, 3.42MB/s]
#
# model-00001-of-00004.safetensors:  24%|▉   | 1.21G/4.98G [00:41<02:29, 25.3MB/s]
# model-00002-of-00004.safetensors:  25%|▉   | 1.23G/5.00G [00:41<02:40, 23.5MB/s]
#
# model-00001-of-00004.safetensors:  24%|▉   | 1.22G/4.98G [00:41<02:32, 24.7MB/s]
#
#
#
#
# consolidated.00.pth:   2%|▎                 | 273M/16.1G [00:41<18:50, 14.0MB/s]
#
#
#
# model-00003-of-00004.safetensors:   5%|▏    | 241M/4.92G [00:41<10:18, 7.56MB/s]
# model-00002-of-00004.safetensors:  25%|▉   | 1.24G/5.00G [00:41<02:37, 23.9MB/s]
#
# model-00001-of-00004.safetensors:  25%|▉   | 1.23G/4.98G [00:42<02:32, 24.6MB/s]
# model-00002-of-00004.safetensors:  25%|▉   | 1.25G/5.00G [00:42<02:35, 24.1MB/s]
#
#
#
#
# consolidated.00.pth:   2%|▎                 | 283M/16.1G [00:42<18:18, 14.4MB/s]
#
# model-00001-of-00004.safetensors:  25%|▉   | 1.24G/4.98G [00:42<02:31, 24.7MB/s]
# model-00002-of-00004.safetensors:  25%|█   | 1.26G/5.00G [00:42<02:32, 24.6MB/s]
#
# model-00001-of-00004.safetensors:  25%|█   | 1.25G/4.98G [00:42<02:25, 25.7MB/s]
# model-00002-of-00004.safetensors:  25%|█   | 1.27G/5.00G [00:43<02:30, 24.8MB/s]
#
#
#
#
# consolidated.00.pth:   2%|▎                 | 294M/16.1G [00:42<17:41, 14.9MB/s]
#
#
#
# model-00003-of-00004.safetensors:   5%|▎    | 252M/4.92G [00:43<10:20, 7.51MB/s]
#
# model-00001-of-00004.safetensors:  25%|█   | 1.26G/4.98G [00:43<02:20, 26.5MB/s]
# model-00002-of-00004.safetensors:  26%|█   | 1.28G/5.00G [00:43<02:31, 24.5MB/s]
#
# model-00001-of-00004.safetensors:  25%|█   | 1.27G/4.98G [00:43<02:16, 27.1MB/s]
#
#
#
#
# consolidated.00.pth:   2%|▎                 | 304M/16.1G [00:43<17:12, 15.3MB/s]
# model-00002-of-00004.safetensors:  26%|█   | 1.29G/5.00G [00:43<02:33, 24.2MB/s]
#
# model-00001-of-00004.safetensors:  26%|█   | 1.28G/4.98G [00:43<02:17, 26.9MB/s]
#
#
#
#
# consolidated.00.pth:   2%|▎                 | 315M/16.1G [00:43<16:39, 15.8MB/s]
#
# model-00001-of-00004.safetensors:  26%|█   | 1.29G/4.98G [00:44<02:13, 27.7MB/s]
# model-00002-of-00004.safetensors:  26%|█   | 1.30G/5.00G [00:44<02:34, 23.9MB/s]
#
#
#
# model-00003-of-00004.safetensors:   5%|▎    | 262M/4.92G [00:44<10:33, 7.34MB/s]
#
# model-00001-of-00004.safetensors:  26%|█   | 1.30G/4.98G [00:44<02:12, 27.7MB/s]
#
#
# model-00004-of-00004.safetensors:  12%|▌    | 136M/1.17G [00:44<05:23, 3.19MB/s]
# model-00002-of-00004.safetensors:  26%|█   | 1.31G/5.00G [00:44<02:45, 22.3MB/s]
#
#
#
#
# consolidated.00.pth:   2%|▎                 | 325M/16.1G [00:44<16:18, 16.1MB/s]
#
# model-00001-of-00004.safetensors:  26%|█   | 1.31G/4.98G [00:45<02:06, 29.1MB/s]
#
# model-00001-of-00004.safetensors:  27%|█   | 1.32G/4.98G [00:45<02:07, 28.7MB/s]
# model-00002-of-00004.safetensors:  26%|█   | 1.32G/5.00G [00:45<02:52, 21.4MB/s]
#
#
#
# model-00003-of-00004.safetensors:   6%|▎    | 273M/4.92G [00:45<09:14, 8.38MB/s]
#
#
#
#
# consolidated.00.pth:   2%|▍                 | 336M/16.1G [00:45<16:12, 16.2MB/s]
#
# model-00001-of-00004.safetensors:  27%|█   | 1.33G/4.98G [00:45<02:06, 28.9MB/s]
# model-00002-of-00004.safetensors:  27%|█   | 1.33G/5.00G [00:46<02:58, 20.5MB/s]
#
# model-00001-of-00004.safetensors:  27%|█   | 1.34G/4.98G [00:46<02:07, 28.5MB/s]
#
#
#
# model-00003-of-00004.safetensors:   6%|▎    | 283M/4.92G [00:46<07:58, 9.69MB/s]
#
#
#
#
# consolidated.00.pth:   2%|▍                 | 346M/16.1G [00:45<16:33, 15.8MB/s]
#
# model-00001-of-00004.safetensors:  27%|█   | 1.35G/4.98G [00:46<02:10, 27.8MB/s]
# model-00002-of-00004.safetensors:  27%|█   | 1.34G/5.00G [00:46<03:08, 19.5MB/s]
#
#
#
# model-00003-of-00004.safetensors:   6%|▎    | 294M/4.92G [00:46<06:49, 11.3MB/s]
#
# model-00001-of-00004.safetensors:  27%|█   | 1.36G/4.98G [00:46<02:10, 27.7MB/s]
#
#
#
#
# consolidated.00.pth:   2%|▍                 | 357M/16.1G [00:46<16:39, 15.7MB/s]
#
#
# model-00004-of-00004.safetensors:  13%|▋    | 147M/1.17G [00:46<04:45, 3.58MB/s]
# model-00002-of-00004.safetensors:  27%|█   | 1.35G/5.00G [00:47<03:19, 18.3MB/s]
#
# model-00001-of-00004.safetensors:  28%|█   | 1.37G/4.98G [00:47<02:11, 27.5MB/s]
#
#
#
# model-00003-of-00004.safetensors:   6%|▎    | 304M/4.92G [00:47<05:58, 12.9MB/s]
#
#
#
#
# consolidated.00.pth:   2%|▍                 | 367M/16.1G [00:47<17:03, 15.3MB/s]
#
# model-00001-of-00004.safetensors:  28%|█   | 1.38G/4.98G [00:47<02:14, 26.6MB/s]
#
#
#
# model-00003-of-00004.safetensors:   6%|▎    | 315M/4.92G [00:47<05:15, 14.6MB/s]
# model-00002-of-00004.safetensors:  27%|█   | 1.36G/5.00G [00:48<03:34, 17.0MB/s]
#
#
#
# model-00003-of-00004.safetensors:   7%|▎    | 325M/4.92G [00:48<04:39, 16.4MB/s]
#
# model-00001-of-00004.safetensors:  28%|█   | 1.39G/4.98G [00:48<02:38, 22.7MB/s]
#
#
# model-00004-of-00004.safetensors:  13%|▋    | 157M/1.17G [00:48<04:00, 4.21MB/s]
#
#
#
#
# consolidated.00.pth:   2%|▍                 | 377M/16.1G [00:48<18:52, 13.8MB/s]
#
# model-00001-of-00004.safetensors:  28%|█▏  | 1.41G/4.98G [00:48<02:26, 24.3MB/s]
#
#
#
# model-00003-of-00004.safetensors:   7%|▎    | 336M/4.92G [00:48<04:19, 17.6MB/s]
# model-00002-of-00004.safetensors:  27%|█   | 1.37G/5.00G [00:49<04:12, 14.3MB/s]
#
# model-00001-of-00004.safetensors:  28%|█▏  | 1.42G/4.98G [00:49<02:30, 23.7MB/s]
#
#
#
# model-00003-of-00004.safetensors:   7%|▎    | 346M/4.92G [00:49<03:58, 19.2MB/s]
#
#
#
#
# consolidated.00.pth:   2%|▍                 | 388M/16.1G [00:49<19:06, 13.7MB/s]
#
#
#
# model-00003-of-00004.safetensors:   7%|▎    | 357M/4.92G [00:49<03:31, 21.5MB/s]
#
# model-00001-of-00004.safetensors:  29%|█▏  | 1.43G/4.98G [00:49<02:23, 24.8MB/s]
#
#
# model-00004-of-00004.safetensors:  14%|▋    | 168M/1.17G [00:49<03:23, 4.93MB/s]
# model-00002-of-00004.safetensors:  28%|█   | 1.38G/5.00G [00:49<04:29, 13.4MB/s]
#
#
#
# model-00003-of-00004.safetensors:   7%|▎    | 367M/4.92G [00:49<03:19, 22.8MB/s]
#
# model-00001-of-00004.safetensors:  29%|█▏  | 1.44G/4.98G [00:50<02:26, 24.1MB/s]
#
#
#
#
# consolidated.00.pth:   2%|▍                 | 398M/16.1G [00:49<19:28, 13.4MB/s]
#
#
#
# model-00003-of-00004.safetensors:   8%|▍    | 377M/4.92G [00:50<03:11, 23.8MB/s]
#
# model-00001-of-00004.safetensors:  29%|█▏  | 1.45G/4.98G [00:50<02:30, 23.5MB/s]
#
#
#
# model-00003-of-00004.safetensors:   8%|▍    | 388M/4.92G [00:50<02:57, 25.6MB/s]
# model-00002-of-00004.safetensors:  28%|█   | 1.39G/5.00G [00:50<04:34, 13.1MB/s]
#
# model-00001-of-00004.safetensors:  29%|█▏  | 1.46G/4.98G [00:50<02:29, 23.5MB/s]
#
#
#
# model-00003-of-00004.safetensors:   8%|▍    | 398M/4.92G [00:50<02:50, 26.6MB/s]
#
#
# model-00004-of-00004.safetensors:  15%|▊    | 178M/1.17G [00:50<02:56, 5.61MB/s]
#
#
#
#
# consolidated.00.pth:   3%|▍                 | 409M/16.1G [00:50<20:10, 12.9MB/s]
#
# model-00001-of-00004.safetensors:  29%|█▏  | 1.47G/4.98G [00:51<02:35, 22.5MB/s]
# model-00002-of-00004.safetensors:  28%|█   | 1.41G/5.00G [00:51<04:25, 13.5MB/s]
#
#
#
# model-00003-of-00004.safetensors:   8%|▍    | 409M/4.92G [00:51<02:55, 25.6MB/s]
#
#
#
# model-00003-of-00004.safetensors:   9%|▍    | 419M/4.92G [00:51<02:56, 25.5MB/s]
#
# model-00001-of-00004.safetensors:  30%|█▏  | 1.48G/4.98G [00:51<02:39, 21.9MB/s]
#
#
#
#
# consolidated.00.pth:   3%|▍                 | 419M/16.1G [00:51<20:54, 12.5MB/s]
# model-00002-of-00004.safetensors:  28%|█▏  | 1.42G/5.00G [00:52<04:29, 13.3MB/s]
#
#
# model-00004-of-00004.safetensors:  16%|▊    | 189M/1.17G [00:52<02:36, 6.24MB/s]
#
#
#
# model-00003-of-00004.safetensors:   9%|▍    | 430M/4.92G [00:52<02:58, 25.1MB/s]
#
# model-00001-of-00004.safetensors:  30%|█▏  | 1.49G/4.98G [00:52<02:51, 20.3MB/s]
#
#
#
# model-00003-of-00004.safetensors:   9%|▍    | 440M/4.92G [00:52<03:18, 22.5MB/s]
#
#
#
#
# consolidated.00.pth:   3%|▍                 | 430M/16.1G [00:52<24:03, 10.8MB/s]
#
# model-00001-of-00004.safetensors:  30%|█▏  | 1.50G/4.98G [00:53<03:13, 18.0MB/s]
#
#
#
# model-00003-of-00004.safetensors:   9%|▍    | 451M/4.92G [00:53<03:21, 22.1MB/s]
# model-00002-of-00004.safetensors:  29%|█▏  | 1.43G/5.00G [00:53<05:03, 11.8MB/s]
#
#
#
# model-00003-of-00004.safetensors:   9%|▍    | 461M/4.92G [00:54<04:12, 17.7MB/s]
#
# model-00001-of-00004.safetensors:  30%|█▏  | 1.51G/4.98G [00:54<04:06, 14.1MB/s]
#
#
# model-00004-of-00004.safetensors:  17%|▊    | 199M/1.17G [00:54<03:07, 5.18MB/s]
#
#
#
# model-00003-of-00004.safetensors:  10%|▍    | 472M/4.92G [00:54<04:46, 15.5MB/s]
#
#
#
#
# consolidated.00.pth:   3%|▍                 | 440M/16.1G [00:55<32:58, 7.90MB/s]
#
# model-00001-of-00004.safetensors:  31%|█▏  | 1.52G/4.98G [00:55<05:02, 11.4MB/s]
# model-00002-of-00004.safetensors:  29%|█▏  | 1.44G/5.00G [00:55<07:39, 7.75MB/s]
#
#
#
# model-00003-of-00004.safetensors:  10%|▍    | 482M/4.92G [00:55<05:10, 14.3MB/s]
#
# model-00001-of-00004.safetensors:  31%|█▏  | 1.53G/4.98G [00:56<04:54, 11.7MB/s]
#
#
#
# model-00003-of-00004.safetensors:  10%|▌    | 493M/4.92G [00:56<04:53, 15.1MB/s]
#
#
#
#
# consolidated.00.pth:   3%|▌                 | 451M/16.1G [00:56<34:08, 7.62MB/s]
# model-00002-of-00004.safetensors:  29%|█▏  | 1.45G/5.00G [00:57<07:21, 8.05MB/s]
#
#
#
# model-00003-of-00004.safetensors:  10%|▌    | 503M/4.92G [00:56<04:24, 16.7MB/s]
#
# model-00001-of-00004.safetensors:  31%|█▏  | 1.54G/4.98G [00:57<04:30, 12.7MB/s]
#
#
#
# model-00003-of-00004.safetensors:  10%|▌    | 514M/4.92G [00:57<04:03, 18.0MB/s]
#
#
# model-00004-of-00004.safetensors:  18%|▉    | 210M/1.17G [00:57<03:18, 4.84MB/s]
#
# model-00001-of-00004.safetensors:  31%|█▏  | 1.55G/4.98G [00:57<04:06, 13.9MB/s]
#
#
#
#
# consolidated.00.pth:   3%|▌                 | 461M/16.1G [00:57<31:31, 8.25MB/s]
#
#
#
# model-00003-of-00004.safetensors:  11%|▌    | 524M/4.92G [00:57<03:40, 19.9MB/s]
# model-00002-of-00004.safetensors:  29%|█▏  | 1.46G/5.00G [00:58<06:45, 8.74MB/s]
#
#
#
# model-00003-of-00004.safetensors:  11%|▌    | 535M/4.92G [00:58<03:31, 20.7MB/s]
#
#
#
# model-00003-of-00004.safetensors:  11%|▌    | 545M/4.92G [00:58<03:04, 23.7MB/s]
#
# model-00001-of-00004.safetensors:  31%|█▎  | 1.56G/4.98G [00:58<04:24, 12.9MB/s]
#
#
#
#
# consolidated.00.pth:   3%|▌                 | 472M/16.1G [00:58<28:33, 9.10MB/s]
# model-00002-of-00004.safetensors:  29%|█▏  | 1.47G/5.00G [00:58<06:21, 9.26MB/s]
#
#
#
# model-00003-of-00004.safetensors:  11%|▌    | 556M/4.92G [00:58<02:57, 24.5MB/s]
#
#
#
# model-00003-of-00004.safetensors:  12%|▌    | 566M/4.92G [00:59<02:47, 25.9MB/s]
#
# model-00001-of-00004.safetensors:  32%|█▎  | 1.57G/4.98G [00:59<04:14, 13.4MB/s]
#
#
#
#
# consolidated.00.pth:   3%|▌                 | 482M/16.1G [00:59<26:16, 9.88MB/s]
#
#
#
# model-00003-of-00004.safetensors:  12%|▌    | 577M/4.92G [00:59<02:49, 25.6MB/s]
# model-00002-of-00004.safetensors:  30%|█▏  | 1.48G/5.00G [01:00<06:10, 9.51MB/s]
#
#
# model-00004-of-00004.safetensors:  19%|▉    | 220M/1.17G [01:00<03:30, 4.51MB/s]
#
# model-00001-of-00004.safetensors:  32%|█▎  | 1.58G/4.98G [01:00<04:16, 13.2MB/s]
#
#
#
# model-00003-of-00004.safetensors:  12%|▌    | 587M/4.92G [01:00<03:09, 22.8MB/s]
#
#
#
#
# consolidated.00.pth:   3%|▌                 | 493M/16.1G [01:00<27:36, 9.40MB/s]
#
#
#
# model-00003-of-00004.safetensors:  12%|▌    | 598M/4.92G [01:00<03:20, 21.5MB/s]
#
# model-00001-of-00004.safetensors:  32%|█▎  | 1.59G/4.98G [01:01<04:28, 12.6MB/s]
# model-00002-of-00004.safetensors:  30%|█▏  | 1.49G/5.00G [01:01<06:44, 8.67MB/s]
#
#
#
# model-00003-of-00004.safetensors:  12%|▌    | 608M/4.92G [01:01<03:47, 18.9MB/s]
# model-00002-of-00004.safetensors:  30%|█▏  | 1.50G/5.00G [01:02<05:51, 9.96MB/s]
#
# model-00001-of-00004.safetensors:  32%|█▎  | 1.60G/4.98G [01:02<04:39, 12.0MB/s]
#
#
#
#
# consolidated.00.pth:   3%|▌                 | 503M/16.1G [01:01<29:47, 8.70MB/s]
#
#
#
# model-00003-of-00004.safetensors:  13%|▋    | 619M/4.92G [01:02<03:52, 18.5MB/s]
# model-00002-of-00004.safetensors:  30%|█▏  | 1.51G/5.00G [01:02<05:10, 11.3MB/s]
#
#
#
# model-00003-of-00004.safetensors:  13%|▋    | 629M/4.92G [01:02<03:54, 18.3MB/s]
#
# model-00001-of-00004.safetensors:  32%|█▎  | 1.61G/4.98G [01:03<04:38, 12.1MB/s]
# model-00002-of-00004.safetensors:  30%|█▏  | 1.52G/5.00G [01:03<04:41, 12.4MB/s]
#
#
#
# model-00003-of-00004.safetensors:  13%|▋    | 640M/4.92G [01:03<03:52, 18.4MB/s]
#
#
#
#
# consolidated.00.pth:   3%|▌                 | 514M/16.1G [01:03<29:42, 8.72MB/s]
#
# model-00001-of-00004.safetensors:  33%|█▎  | 1.63G/4.98G [01:03<04:27, 12.5MB/s]
#
#
# model-00004-of-00004.safetensors:  20%|▉    | 231M/1.17G [01:03<04:01, 3.88MB/s]
#
#
#
# model-00003-of-00004.safetensors:  13%|▋    | 650M/4.92G [01:03<03:49, 18.6MB/s]
# model-00002-of-00004.safetensors:  31%|█▏  | 1.53G/5.00G [01:04<04:16, 13.5MB/s]
#
# model-00001-of-00004.safetensors:  33%|█▎  | 1.64G/4.98G [01:04<04:04, 13.7MB/s]
#
#
#
# model-00003-of-00004.safetensors:  13%|▋    | 661M/4.92G [01:04<03:44, 18.9MB/s]
#
#
#
#
# consolidated.00.pth:   3%|▌                 | 524M/16.1G [01:04<28:28, 9.09MB/s]
# model-00002-of-00004.safetensors:  31%|█▏  | 1.54G/5.00G [01:04<03:59, 14.5MB/s]
#
# model-00001-of-00004.safetensors:  33%|█▎  | 1.65G/4.98G [01:05<03:45, 14.8MB/s]
#
#
#
# model-00003-of-00004.safetensors:  14%|▋    | 671M/4.92G [01:04<03:40, 19.3MB/s]
# model-00002-of-00004.safetensors:  31%|█▏  | 1.55G/5.00G [01:05<03:42, 15.5MB/s]
#
# model-00001-of-00004.safetensors:  33%|█▎  | 1.66G/4.98G [01:05<03:35, 15.4MB/s]
#
#
#
#
# consolidated.00.pth:   3%|▌                 | 535M/16.1G [01:05<27:54, 9.27MB/s]
#
#
#
# model-00003-of-00004.safetensors:  14%|▋    | 682M/4.92G [01:05<03:50, 18.4MB/s]
# model-00002-of-00004.safetensors:  31%|█▏  | 1.56G/5.00G [01:05<03:34, 16.0MB/s]
#
# model-00001-of-00004.safetensors:  34%|█▎  | 1.67G/4.98G [01:06<03:20, 16.5MB/s]
#
#
#
# model-00003-of-00004.safetensors:  14%|▋    | 692M/4.92G [01:06<03:46, 18.7MB/s]
# model-00002-of-00004.safetensors:  31%|█▎  | 1.57G/5.00G [01:06<03:22, 17.0MB/s]
#
# model-00001-of-00004.safetensors:  34%|█▎  | 1.68G/4.98G [01:06<03:03, 17.9MB/s]
#
#
# model-00004-of-00004.safetensors:  21%|█    | 241M/1.17G [01:06<04:00, 3.85MB/s]
# model-00002-of-00004.safetensors:  32%|█▎  | 1.58G/5.00G [01:06<03:06, 18.3MB/s]
#
#
#
#
# consolidated.00.pth:   3%|▌                 | 545M/16.1G [01:06<28:36, 9.04MB/s]
#
#
#
# model-00003-of-00004.safetensors:  14%|▋    | 703M/4.92G [01:06<04:13, 16.6MB/s]
#
# model-00001-of-00004.safetensors:  34%|█▎  | 1.69G/4.98G [01:07<02:54, 18.9MB/s]
# model-00002-of-00004.safetensors:  32%|█▎  | 1.59G/5.00G [01:07<03:02, 18.7MB/s]
#
#
#
# model-00003-of-00004.safetensors:  15%|▋    | 713M/4.92G [01:07<04:05, 17.2MB/s]
#
# model-00001-of-00004.safetensors:  34%|█▎  | 1.70G/4.98G [01:07<02:50, 19.2MB/s]
#
#
#
#
# consolidated.00.pth:   3%|▌                 | 556M/16.1G [01:07<27:09, 9.51MB/s]
# model-00002-of-00004.safetensors:  32%|█▎  | 1.60G/5.00G [01:08<03:11, 17.8MB/s]
#
#
#
# model-00003-of-00004.safetensors:  15%|▋    | 724M/4.92G [01:07<03:52, 18.0MB/s]
#
# model-00001-of-00004.safetensors:  34%|█▎  | 1.71G/4.98G [01:08<02:55, 18.6MB/s]
#
#
#
# model-00003-of-00004.safetensors:  15%|▋    | 734M/4.92G [01:08<03:44, 18.7MB/s]
# model-00002-of-00004.safetensors:  32%|█▎  | 1.61G/5.00G [01:08<03:21, 16.8MB/s]
#
#
#
#
# consolidated.00.pth:   4%|▋                 | 566M/16.1G [01:08<26:10, 9.87MB/s]
#
# model-00001-of-00004.safetensors:  35%|█▍  | 1.72G/4.98G [01:08<02:56, 18.5MB/s]
#
#
#
# model-00003-of-00004.safetensors:  15%|▊    | 744M/4.92G [01:08<03:38, 19.1MB/s]
# model-00002-of-00004.safetensors:  33%|█▎  | 1.63G/5.00G [01:09<03:15, 17.2MB/s]
#
# model-00001-of-00004.safetensors:  35%|█▍  | 1.73G/4.98G [01:09<02:48, 19.3MB/s]
#
#
# model-00004-of-00004.safetensors:  22%|█    | 252M/1.17G [01:09<04:02, 3.77MB/s]
#
#
#
# model-00003-of-00004.safetensors:  15%|▊    | 755M/4.92G [01:09<03:23, 20.4MB/s]
#
#
#
#
# consolidated.00.pth:   4%|▋                 | 577M/16.1G [01:09<24:22, 10.6MB/s]
#
# model-00001-of-00004.safetensors:  35%|█▍  | 1.74G/4.98G [01:09<02:45, 19.6MB/s]
# model-00002-of-00004.safetensors:  33%|█▎  | 1.64G/5.00G [01:10<03:30, 16.0MB/s]
#
#
#
# model-00003-of-00004.safetensors:  16%|▊    | 765M/4.92G [01:09<03:25, 20.2MB/s]
#
# model-00001-of-00004.safetensors:  35%|█▍  | 1.75G/4.98G [01:10<02:42, 19.9MB/s]
#
#
#
#
# consolidated.00.pth:   4%|▋                 | 587M/16.1G [01:10<23:48, 10.8MB/s]
#
#
#
# model-00003-of-00004.safetensors:  16%|▊    | 776M/4.92G [01:10<03:16, 21.1MB/s]
# model-00002-of-00004.safetensors:  33%|█▎  | 1.65G/5.00G [01:10<03:32, 15.8MB/s]
#
# model-00001-of-00004.safetensors:  35%|█▍  | 1.76G/4.98G [01:10<02:36, 20.5MB/s]
#
#
#
# model-00003-of-00004.safetensors:  16%|▊    | 786M/4.92G [01:10<03:12, 21.4MB/s]
#
# model-00001-of-00004.safetensors:  36%|█▍  | 1.77G/4.98G [01:11<02:30, 21.2MB/s]
#
#
#
#
# consolidated.00.pth:   4%|▋                 | 598M/16.1G [01:10<22:26, 11.5MB/s]
# model-00002-of-00004.safetensors:  33%|█▎  | 1.66G/5.00G [01:11<03:33, 15.7MB/s]
#
#
#
# model-00003-of-00004.safetensors:  16%|▊    | 797M/4.92G [01:11<03:06, 22.1MB/s]
#
# model-00001-of-00004.safetensors:  36%|█▍  | 1.78G/4.98G [01:11<02:27, 21.6MB/s]
#
#
#
# model-00003-of-00004.safetensors:  16%|▊    | 807M/4.92G [01:11<03:07, 22.0MB/s]
# model-00002-of-00004.safetensors:  33%|█▎  | 1.67G/5.00G [01:12<03:34, 15.5MB/s]
#
# model-00001-of-00004.safetensors:  36%|█▍  | 1.79G/4.98G [01:12<02:23, 22.2MB/s]
#
#
#
#
# consolidated.00.pth:   4%|▋                 | 608M/16.1G [01:11<21:50, 11.8MB/s]
#
#
# model-00004-of-00004.safetensors:  22%|█    | 262M/1.17G [01:12<03:56, 3.84MB/s]
#
#
#
# model-00003-of-00004.safetensors:  17%|▊    | 818M/4.92G [01:12<03:03, 22.4MB/s]
#
# model-00001-of-00004.safetensors:  36%|█▍  | 1.80G/4.98G [01:12<02:17, 23.1MB/s]
#
#
#
# model-00003-of-00004.safetensors:  17%|▊    | 828M/4.92G [01:12<03:03, 22.3MB/s]
#
# model-00001-of-00004.safetensors:  36%|█▍  | 1.81G/4.98G [01:12<02:08, 24.6MB/s]
#
#
#
#
# consolidated.00.pth:   4%|▋                 | 619M/16.1G [01:12<21:00, 12.3MB/s]
# model-00002-of-00004.safetensors:  34%|█▎  | 1.68G/5.00G [01:13<04:09, 13.3MB/s]
#
# model-00001-of-00004.safetensors:  37%|█▍  | 1.82G/4.98G [01:13<02:05, 25.1MB/s]
#
#
#
# model-00003-of-00004.safetensors:  17%|▊    | 839M/4.92G [01:13<03:00, 22.6MB/s]
# model-00002-of-00004.safetensors:  34%|█▎  | 1.69G/5.00G [01:13<03:49, 14.4MB/s]
#
#
#
#
# consolidated.00.pth:   4%|▋                 | 629M/16.1G [01:13<20:44, 12.4MB/s]
#
# model-00001-of-00004.safetensors:  37%|█▍  | 1.84G/4.98G [01:13<02:06, 24.9MB/s]
#
#
#
# model-00003-of-00004.safetensors:  17%|▊    | 849M/4.92G [01:13<02:56, 23.1MB/s]
#
# model-00001-of-00004.safetensors:  37%|█▍  | 1.85G/4.98G [01:14<02:06, 24.8MB/s]
#
#
# model-00004-of-00004.safetensors:  23%|█▏   | 273M/1.17G [01:14<03:36, 4.13MB/s]
#
#
#
# model-00003-of-00004.safetensors:  17%|▊    | 860M/4.92G [01:14<03:08, 21.5MB/s]
# model-00002-of-00004.safetensors:  34%|█▎  | 1.70G/5.00G [01:14<03:42, 14.8MB/s]
#
#
#
#
# consolidated.00.pth:   4%|▋                 | 640M/16.1G [01:14<20:30, 12.5MB/s]
#
# model-00001-of-00004.safetensors:  37%|█▍  | 1.86G/4.98G [01:14<02:13, 23.3MB/s]
#
#
#
# model-00003-of-00004.safetensors:  18%|▉    | 870M/4.92G [01:14<03:16, 20.6MB/s]
# model-00002-of-00004.safetensors:  34%|█▎  | 1.71G/5.00G [01:15<03:38, 15.0MB/s]
#
# model-00001-of-00004.safetensors:  38%|█▌  | 1.87G/4.98G [01:15<02:13, 23.3MB/s]
#
#
#
#
# consolidated.00.pth:   4%|▋                 | 650M/16.1G [01:15<20:16, 12.7MB/s]
#
#
#
# model-00003-of-00004.safetensors:  18%|▉    | 881M/4.92G [01:15<03:14, 20.7MB/s]
# ...
#
#
#
#
# consolidated.00.pth:  88%|██████████████▉  | 14.1G/16.1G [07:58<00:45, 42.2MB/s]
#
#
#
#
# consolidated.00.pth:  88%|██████████████▉  | 14.1G/16.1G [07:58<00:45, 42.4MB/s]
#
#
#
#
# consolidated.00.pth:  88%|██████████████▉  | 14.2G/16.1G [07:58<00:45, 42.0MB/s]
#
#
#
#
# consolidated.00.pth:  88%|██████████████▉  | 14.2G/16.1G [07:58<00:45, 41.9MB/s]
#
#
#
#
# consolidated.00.pth:  88%|███████████████  | 14.2G/16.1G [07:59<00:44, 41.9MB/s]
#
#
#
#
# consolidated.00.pth:  88%|███████████████  | 14.2G/16.1G [07:59<00:44, 42.0MB/s]
#
#
#
#
# consolidated.00.pth:  88%|███████████████  | 14.2G/16.1G [07:59<00:44, 42.2MB/s]
#
#
#
#
# consolidated.00.pth:  88%|███████████████  | 14.2G/16.1G [07:59<00:43, 42.2MB/s]
#
#
#
#
# consolidated.00.pth:  89%|███████████████  | 14.2G/16.1G [08:00<00:43, 42.4MB/s]
#
#
#
#
# consolidated.00.pth:  89%|███████████████  | 14.2G/16.1G [08:00<00:43, 42.5MB/s]
#
#
#
#
# consolidated.00.pth:  89%|███████████████  | 14.2G/16.1G [08:00<00:43, 42.2MB/s]
#
#
#
#
# consolidated.00.pth:  89%|███████████████  | 14.3G/16.1G [08:00<00:42, 42.5MB/s]
#
#
#
#
# consolidated.00.pth:  89%|███████████████  | 14.3G/16.1G [08:01<00:42, 42.6MB/s]
#
#
#
#
# consolidated.00.pth:  89%|███████████████  | 14.3G/16.1G [08:01<00:41, 42.7MB/s]
#
#
#
#
# consolidated.00.pth:  89%|███████████████  | 14.3G/16.1G [08:01<00:41, 42.7MB/s]
#
#
#
#
# consolidated.00.pth:  89%|███████████████▏ | 14.3G/16.1G [08:01<00:41, 42.9MB/s]
#
#
#
#
# consolidated.00.pth:  89%|███████████████▏ | 14.3G/16.1G [08:02<00:40, 42.9MB/s]
#
#
#
#
# consolidated.00.pth:  89%|███████████████▏ | 14.3G/16.1G [08:02<00:40, 42.8MB/s]
#
#
#
#
# consolidated.00.pth:  89%|███████████████▏ | 14.3G/16.1G [08:02<00:40, 42.7MB/s]
#
#
#
#
# consolidated.00.pth:  89%|███████████████▏ | 14.3G/16.1G [08:02<00:40, 42.6MB/s]
#
#
#
#
# consolidated.00.pth:  89%|███████████████▏ | 14.3G/16.1G [08:03<00:40, 42.3MB/s]
#
#
#
#
# consolidated.00.pth:  89%|███████████████▏ | 14.4G/16.1G [08:03<00:40, 42.3MB/s]
#
#
#
#
# consolidated.00.pth:  89%|███████████████▏ | 14.4G/16.1G [08:03<00:39, 42.5MB/s]
#
#
#
#
# consolidated.00.pth:  90%|███████████████▏ | 14.4G/16.1G [08:03<00:39, 42.7MB/s]
#
#
#
#
# consolidated.00.pth:  90%|███████████████▏ | 14.4G/16.1G [08:04<00:39, 42.6MB/s]
#
#
#
#
# consolidated.00.pth:  90%|███████████████▏ | 14.4G/16.1G [08:04<00:39, 42.7MB/s]
#
#
#
#
# consolidated.00.pth:  90%|███████████████▎ | 14.4G/16.1G [08:04<00:38, 42.6MB/s]
#
#
#
#
# consolidated.00.pth:  90%|███████████████▎ | 14.4G/16.1G [08:04<00:38, 42.6MB/s]
#
#
#
#
# consolidated.00.pth:  90%|███████████████▎ | 14.4G/16.1G [08:05<00:38, 42.6MB/s]
#
#
#
#
# consolidated.00.pth:  90%|███████████████▎ | 14.4G/16.1G [08:05<00:38, 42.5MB/s]
#
#
#
#
# consolidated.00.pth:  90%|███████████████▎ | 14.4G/16.1G [08:05<00:37, 42.6MB/s]
#
#
#
#
# consolidated.00.pth:  90%|███████████████▎ | 14.5G/16.1G [08:05<00:37, 42.2MB/s]
#
#
#
#
# consolidated.00.pth:  90%|███████████████▎ | 14.5G/16.1G [08:06<00:37, 42.1MB/s]
#
#
#
#
# consolidated.00.pth:  90%|███████████████▎ | 14.5G/16.1G [08:06<00:37, 42.3MB/s]
#
#
#
#
# consolidated.00.pth:  90%|███████████████▎ | 14.5G/16.1G [08:06<00:37, 42.2MB/s]
#
#
#
#
# consolidated.00.pth:  90%|███████████████▎ | 14.5G/16.1G [08:06<00:37, 41.7MB/s]
#
#
#
#
# consolidated.00.pth:  90%|███████████████▎ | 14.5G/16.1G [08:07<00:38, 40.1MB/s]
#
#
#
#
# consolidated.00.pth:  90%|███████████████▎ | 14.5G/16.1G [08:07<00:37, 40.7MB/s]
#
#
#
#
# consolidated.00.pth:  90%|███████████████▍ | 14.5G/16.1G [08:07<00:37, 40.7MB/s]
#
#
#
#
# consolidated.00.pth:  91%|███████████████▍ | 14.5G/16.1G [08:07<00:42, 35.4MB/s]
#
#
#
#
# consolidated.00.pth:  91%|███████████████▍ | 14.6G/16.1G [08:08<00:34, 43.8MB/s]
#
#
#
#
# consolidated.00.pth:  91%|███████████████▍ | 14.6G/16.1G [08:08<00:34, 43.2MB/s]
#
#
#
#
# consolidated.00.pth:  91%|███████████████▍ | 14.6G/16.1G [08:08<00:34, 43.1MB/s]
#
#
#
#
# consolidated.00.pth:  91%|███████████████▍ | 14.6G/16.1G [08:08<00:34, 43.1MB/s]
#
#
#
#
# consolidated.00.pth:  91%|███████████████▍ | 14.6G/16.1G [08:09<00:34, 43.0MB/s]
#
#
#
#
# consolidated.00.pth:  91%|███████████████▍ | 14.6G/16.1G [08:09<00:33, 43.0MB/s]
#
#
#
#
# consolidated.00.pth:  91%|███████████████▍ | 14.6G/16.1G [08:09<00:33, 43.0MB/s]
#
#
#
#
# consolidated.00.pth:  91%|███████████████▍ | 14.6G/16.1G [08:09<00:33, 42.8MB/s]
#
#
#
#
# consolidated.00.pth:  91%|███████████████▍ | 14.6G/16.1G [08:10<00:33, 42.9MB/s]
#
#
#
#
# consolidated.00.pth:  91%|███████████████▌ | 14.6G/16.1G [08:10<00:32, 42.9MB/s]
#
#
#
#
# consolidated.00.pth:  91%|███████████████▌ | 14.7G/16.1G [08:10<00:32, 42.8MB/s]
#
#
#
#
# consolidated.00.pth:  91%|███████████████▌ | 14.7G/16.1G [08:10<00:32, 42.7MB/s]
#
#
#
#
# consolidated.00.pth:  91%|███████████████▌ | 14.7G/16.1G [08:11<00:32, 42.6MB/s]
#
#
#
#
# consolidated.00.pth:  91%|███████████████▌ | 14.7G/16.1G [08:11<00:32, 42.7MB/s]
#
#
#
#
# consolidated.00.pth:  92%|███████████████▌ | 14.7G/16.1G [08:11<00:32, 42.4MB/s]
#
#
#
#
# consolidated.00.pth:  92%|███████████████▌ | 14.7G/16.1G [08:11<00:31, 42.8MB/s]
#
#
#
#
# consolidated.00.pth:  92%|███████████████▌ | 14.7G/16.1G [08:11<00:31, 42.8MB/s]
#
#
#
#
# consolidated.00.pth:  92%|███████████████▌ | 14.7G/16.1G [08:12<00:30, 42.9MB/s]
#
#
#
#
# consolidated.00.pth:  92%|███████████████▌ | 14.7G/16.1G [08:12<00:31, 42.5MB/s]
#
#
#
#
# consolidated.00.pth:  92%|███████████████▌ | 14.8G/16.1G [08:12<00:30, 42.5MB/s]
#
#
#
#
# consolidated.00.pth:  92%|███████████████▋ | 14.8G/16.1G [08:13<00:31, 41.4MB/s]
#
#
#
#
# consolidated.00.pth:  92%|███████████████▋ | 14.8G/16.1G [08:13<00:30, 41.5MB/s]
#
#
#
#
# consolidated.00.pth:  92%|███████████████▋ | 14.8G/16.1G [08:13<00:30, 42.0MB/s]
#
#
#
#
# consolidated.00.pth:  92%|███████████████▋ | 14.8G/16.1G [08:13<00:30, 41.9MB/s]
#
#
#
#
# consolidated.00.pth:  92%|███████████████▋ | 14.8G/16.1G [08:14<00:29, 41.9MB/s]
#
#
#
#
# consolidated.00.pth:  92%|███████████████▋ | 14.8G/16.1G [08:14<00:29, 42.0MB/s]
#
#
#
#
# consolidated.00.pth:  92%|███████████████▋ | 14.8G/16.1G [08:14<00:29, 42.2MB/s]
#
#
#
#
# consolidated.00.pth:  92%|███████████████▋ | 14.8G/16.1G [08:14<00:28, 42.3MB/s]
#
#
#
#
# consolidated.00.pth:  92%|███████████████▋ | 14.8G/16.1G [08:14<00:28, 42.4MB/s]
#
#
#
#
# consolidated.00.pth:  93%|███████████████▋ | 14.9G/16.1G [08:15<00:28, 42.7MB/s]
#
#
#
#
# consolidated.00.pth:  93%|███████████████▋ | 14.9G/16.1G [08:15<00:28, 42.4MB/s]
#
#
#
#
# consolidated.00.pth:  93%|███████████████▋ | 14.9G/16.1G [08:15<00:27, 42.2MB/s]
#
#
#
#
# consolidated.00.pth:  93%|███████████████▊ | 14.9G/16.1G [08:15<00:27, 42.4MB/s]
#
#
#
#
# consolidated.00.pth:  93%|███████████████▊ | 14.9G/16.1G [08:16<00:27, 42.3MB/s]
#
#
#
#
# consolidated.00.pth:  93%|███████████████▊ | 14.9G/16.1G [08:16<00:27, 42.2MB/s]
#
#
#
#
# consolidated.00.pth:  93%|███████████████▊ | 14.9G/16.1G [08:16<00:27, 42.1MB/s]
#
#
#
#
# consolidated.00.pth:  93%|███████████████▊ | 14.9G/16.1G [08:16<00:26, 42.2MB/s]
#
#
#
#
# consolidated.00.pth:  93%|███████████████▊ | 14.9G/16.1G [08:17<00:26, 42.1MB/s]
#
#
#
#
# consolidated.00.pth:  93%|███████████████▊ | 15.0G/16.1G [08:17<00:26, 42.2MB/s]
#
#
#
#
# consolidated.00.pth:  93%|███████████████▊ | 15.0G/16.1G [08:17<00:26, 41.0MB/s]
#
#
#
#
# consolidated.00.pth:  93%|███████████████▊ | 15.0G/16.1G [08:18<00:28, 38.8MB/s]
#
#
#
#
# consolidated.00.pth:  93%|███████████████▊ | 15.0G/16.1G [08:18<00:26, 40.0MB/s]
#
#
#
#
# consolidated.00.pth:  93%|███████████████▊ | 15.0G/16.1G [08:18<00:26, 40.3MB/s]
#
#
#
#
# consolidated.00.pth:  93%|███████████████▉ | 15.0G/16.1G [08:18<00:25, 41.0MB/s]
#
#
#
#
# consolidated.00.pth:  93%|███████████████▉ | 15.0G/16.1G [08:19<00:25, 41.4MB/s]
#
#
#
#
# consolidated.00.pth:  94%|███████████████▉ | 15.0G/16.1G [08:19<00:24, 41.9MB/s]
#
#
#
#
# consolidated.00.pth:  94%|███████████████▉ | 15.0G/16.1G [08:19<00:24, 42.2MB/s]
#
#
#
#
# consolidated.00.pth:  94%|███████████████▉ | 15.0G/16.1G [08:19<00:23, 42.3MB/s]
#
#
#
#
# consolidated.00.pth:  94%|███████████████▉ | 15.1G/16.1G [08:20<00:23, 42.5MB/s]
#
#
#
#
# consolidated.00.pth:  94%|███████████████▉ | 15.1G/16.1G [08:20<00:23, 41.8MB/s]
#
#
#
#
# consolidated.00.pth:  94%|███████████████▉ | 15.1G/16.1G [08:20<00:23, 42.1MB/s]
#
#
#
#
# consolidated.00.pth:  94%|███████████████▉ | 15.1G/16.1G [08:20<00:22, 42.3MB/s]
#
#
#
#
# consolidated.00.pth:  94%|███████████████▉ | 15.1G/16.1G [08:21<00:22, 42.4MB/s]
#
#
#
#
# consolidated.00.pth:  94%|███████████████▉ | 15.1G/16.1G [08:21<00:22, 42.6MB/s]
#
#
#
#
# consolidated.00.pth:  94%|████████████████ | 15.1G/16.1G [08:21<00:22, 42.6MB/s]
#
#
#
#
# consolidated.00.pth:  94%|████████████████ | 15.1G/16.1G [08:21<00:21, 42.5MB/s]
#
#
#
#
# consolidated.00.pth:  94%|████████████████ | 15.1G/16.1G [08:21<00:21, 42.5MB/s]
#
#
#
#
# consolidated.00.pth:  94%|████████████████ | 15.2G/16.1G [08:22<00:20, 45.0MB/s]
#
#
#
#
# consolidated.00.pth:  94%|████████████████ | 15.2G/16.1G [08:22<00:16, 53.5MB/s]
#
#
#
#
# consolidated.00.pth:  94%|████████████████ | 15.2G/16.1G [08:22<00:14, 61.3MB/s]
#
#
#
#
# consolidated.00.pth:  95%|████████████████ | 15.2G/16.1G [08:22<00:12, 68.7MB/s]
#
#
#
#
# consolidated.00.pth:  95%|████████████████ | 15.2G/16.1G [08:22<00:13, 65.2MB/s]
#
#
#
#
# consolidated.00.pth:  95%|████████████████ | 15.2G/16.1G [08:22<00:15, 56.2MB/s]
#
#
#
#
# consolidated.00.pth:  95%|████████████████ | 15.2G/16.1G [08:23<00:16, 51.5MB/s]
#
#
#
#
# consolidated.00.pth:  95%|████████████████ | 15.2G/16.1G [08:23<00:17, 48.3MB/s]
#
#
#
#
# consolidated.00.pth:  95%|████████████████▏| 15.2G/16.1G [08:23<00:17, 46.6MB/s]
#
#
#
#
# consolidated.00.pth:  95%|████████████████▏| 15.2G/16.1G [08:23<00:17, 45.3MB/s]
#
#
#
#
# consolidated.00.pth:  95%|████████████████▏| 15.3G/16.1G [08:24<00:18, 44.3MB/s]
#
#
#
#
# consolidated.00.pth:  95%|████████████████▏| 15.3G/16.1G [08:24<00:18, 43.6MB/s]
#
#
#
#
# consolidated.00.pth:  95%|████████████████▏| 15.3G/16.1G [08:24<00:18, 43.3MB/s]
#
#
#
#
# consolidated.00.pth:  95%|████████████████▏| 15.3G/16.1G [08:24<00:18, 42.8MB/s]
#
#
#
#
# consolidated.00.pth:  95%|████████████████▏| 15.3G/16.1G [08:25<00:17, 42.6MB/s]
#
#
#
#
# consolidated.00.pth:  95%|████████████████▏| 15.3G/16.1G [08:25<00:17, 42.1MB/s]
#
#
#
#
# consolidated.00.pth:  95%|████████████████▏| 15.3G/16.1G [08:25<00:17, 42.0MB/s]
#
#
#
#
# consolidated.00.pth:  95%|████████████████▏| 15.3G/16.1G [08:25<00:17, 42.0MB/s]
#
#
#
#
# consolidated.00.pth:  96%|████████████████▏| 15.3G/16.1G [08:26<00:17, 42.3MB/s]
#
#
#
#
# consolidated.00.pth:  96%|████████████████▏| 15.4G/16.1G [08:26<00:16, 42.2MB/s]
#
#
#
#
# consolidated.00.pth:  96%|████████████████▎| 15.4G/16.1G [08:26<00:16, 42.3MB/s]
#
#
#
#
# consolidated.00.pth:  96%|████████████████▎| 15.4G/16.1G [08:26<00:16, 42.3MB/s]
#
#
#
#
# consolidated.00.pth:  96%|████████████████▎| 15.4G/16.1G [08:27<00:16, 42.3MB/s]
#
#
#
#
# consolidated.00.pth:  96%|████████████████▎| 15.4G/16.1G [08:27<00:15, 42.0MB/s]
#
#
#
#
# consolidated.00.pth:  96%|████████████████▎| 15.4G/16.1G [08:27<00:15, 42.4MB/s]
#
#
#
#
# consolidated.00.pth:  96%|████████████████▎| 15.4G/16.1G [08:27<00:15, 42.5MB/s]
#
#
#
#
# consolidated.00.pth:  96%|████████████████▎| 15.4G/16.1G [08:28<00:15, 42.4MB/s]
#
#
#
#
# consolidated.00.pth:  96%|████████████████▎| 15.4G/16.1G [08:28<00:14, 42.6MB/s]
#
#
#
#
# consolidated.00.pth:  96%|████████████████▎| 15.4G/16.1G [08:28<00:16, 36.4MB/s]
#
#
#
#
# consolidated.00.pth:  96%|████████████████▎| 15.5G/16.1G [08:29<00:19, 31.4MB/s]
#
#
#
#
# consolidated.00.pth:  96%|████████████████▎| 15.5G/16.1G [08:29<00:17, 34.0MB/s]
#
#
#
#
# consolidated.00.pth:  96%|████████████████▍| 15.5G/16.1G [08:29<00:16, 36.3MB/s]
#
#
#
#
# consolidated.00.pth:  96%|████████████████▍| 15.5G/16.1G [08:29<00:15, 37.9MB/s]
#
#
#
#
# consolidated.00.pth:  96%|████████████████▍| 15.5G/16.1G [08:30<00:14, 39.1MB/s]
#
#
#
#
# consolidated.00.pth:  97%|████████████████▍| 15.5G/16.1G [08:30<00:13, 39.7MB/s]
#
#
#
#
# consolidated.00.pth:  97%|████████████████▍| 15.5G/16.1G [08:30<00:13, 40.6MB/s]
#
#
#
#
# consolidated.00.pth:  97%|████████████████▍| 15.5G/16.1G [08:30<00:12, 40.9MB/s]
#
#
#
#
# consolidated.00.pth:  97%|████████████████▍| 15.5G/16.1G [08:31<00:12, 41.3MB/s]
#
#
#
#
# consolidated.00.pth:  97%|████████████████▍| 15.6G/16.1G [08:31<00:12, 41.8MB/s]
#
#
#
#
# consolidated.00.pth:  97%|████████████████▍| 15.6G/16.1G [08:31<00:11, 42.1MB/s]
#
#
#
#
# consolidated.00.pth:  97%|████████████████▍| 15.6G/16.1G [08:31<00:11, 42.2MB/s]
#
#
#
#
# consolidated.00.pth:  97%|████████████████▍| 15.6G/16.1G [08:32<00:11, 42.0MB/s]
#
#
#
#
# consolidated.00.pth:  97%|████████████████▌| 15.6G/16.1G [08:32<00:11, 42.3MB/s]
#
#
#
#
# consolidated.00.pth:  97%|████████████████▌| 15.6G/16.1G [08:32<00:10, 42.0MB/s]
#
#
#
#
# consolidated.00.pth:  97%|████████████████▌| 15.6G/16.1G [08:32<00:10, 42.1MB/s]
#
#
#
#
# consolidated.00.pth:  97%|████████████████▌| 15.6G/16.1G [08:33<00:10, 42.5MB/s]
#
#
#
#
# consolidated.00.pth:  97%|████████████████▌| 15.6G/16.1G [08:33<00:10, 42.3MB/s]
#
#
#
#
# consolidated.00.pth:  97%|████████████████▌| 15.6G/16.1G [08:33<00:09, 42.5MB/s]
#
#
#
#
# consolidated.00.pth:  97%|████████████████▌| 15.7G/16.1G [08:33<00:09, 42.6MB/s]
#
#
#
#
# consolidated.00.pth:  98%|████████████████▌| 15.7G/16.1G [08:34<00:09, 42.4MB/s]
#
#
#
#
# consolidated.00.pth:  98%|████████████████▌| 15.7G/16.1G [08:34<00:09, 42.3MB/s]
#
#
#
#
# consolidated.00.pth:  98%|████████████████▌| 15.7G/16.1G [08:34<00:08, 42.5MB/s]
#
#
#
#
# consolidated.00.pth:  98%|████████████████▌| 15.7G/16.1G [08:34<00:08, 42.4MB/s]
#
#
#
#
# consolidated.00.pth:  98%|████████████████▋| 15.7G/16.1G [08:35<00:08, 42.6MB/s]
#
#
#
#
# consolidated.00.pth:  98%|████████████████▋| 15.7G/16.1G [08:35<00:08, 42.4MB/s]
#
#
#
#
# consolidated.00.pth:  98%|████████████████▋| 15.7G/16.1G [08:35<00:09, 33.9MB/s]
#
#
#
#
# consolidated.00.pth:  98%|████████████████▋| 15.7G/16.1G [08:36<00:07, 41.2MB/s]
#
#
#
#
# consolidated.00.pth:  98%|████████████████▋| 15.7G/16.1G [08:36<00:06, 47.1MB/s]
#
#
#
#
# consolidated.00.pth:  98%|████████████████▋| 15.8G/16.1G [08:36<00:06, 45.3MB/s]
#
#
#
#
# consolidated.00.pth:  98%|████████████████▋| 15.8G/16.1G [08:36<00:06, 44.4MB/s]
#
#
#
#
# consolidated.00.pth:  98%|████████████████▋| 15.8G/16.1G [08:36<00:06, 43.7MB/s]
#
#
#
#
# consolidated.00.pth:  98%|████████████████▋| 15.8G/16.1G [08:37<00:06, 43.1MB/s]
#
#
#
#
# consolidated.00.pth:  98%|████████████████▋| 15.8G/16.1G [08:37<00:06, 42.8MB/s]
#
#
#
#
# consolidated.00.pth:  98%|████████████████▋| 15.8G/16.1G [08:37<00:05, 42.7MB/s]
#
#
#
#
# consolidated.00.pth:  99%|████████████████▋| 15.8G/16.1G [08:37<00:05, 42.5MB/s]
#
#
#
#
# consolidated.00.pth:  99%|████████████████▊| 15.8G/16.1G [08:38<00:05, 42.5MB/s]
#
#
#
#
# consolidated.00.pth:  99%|████████████████▊| 15.8G/16.1G [08:38<00:05, 42.3MB/s]
#
#
#
#
# consolidated.00.pth:  99%|████████████████▊| 15.9G/16.1G [08:38<00:04, 42.2MB/s]
#
#
#
#
# consolidated.00.pth:  99%|████████████████▊| 15.9G/16.1G [08:38<00:04, 42.1MB/s]
#
#
#
#
# consolidated.00.pth:  99%|████████████████▊| 15.9G/16.1G [08:39<00:04, 41.6MB/s]
#
#
#
#
# consolidated.00.pth:  99%|████████████████▊| 15.9G/16.1G [08:39<00:04, 41.1MB/s]
#
#
#
#
# consolidated.00.pth:  99%|████████████████▊| 15.9G/16.1G [08:39<00:05, 31.9MB/s]
#
#
#
#
# consolidated.00.pth:  99%|████████████████▊| 15.9G/16.1G [08:40<00:04, 33.8MB/s]
#
#
#
#
# consolidated.00.pth:  99%|████████████████▊| 15.9G/16.1G [08:40<00:03, 36.0MB/s]
#
#
#
#
# consolidated.00.pth:  99%|████████████████▊| 15.9G/16.1G [08:40<00:03, 37.9MB/s]
#
#
#
#
# consolidated.00.pth:  99%|████████████████▊| 15.9G/16.1G [08:40<00:03, 38.4MB/s]
#
#
#
#
# consolidated.00.pth:  99%|████████████████▉| 15.9G/16.1G [08:41<00:02, 39.3MB/s]
#
#
#
#
# consolidated.00.pth:  99%|████████████████▉| 16.0G/16.1G [08:41<00:02, 40.0MB/s]
#
#
#
#
# consolidated.00.pth:  99%|████████████████▉| 16.0G/16.1G [08:41<00:02, 40.6MB/s]
#
#
#
#
# consolidated.00.pth:  99%|████████████████▉| 16.0G/16.1G [08:41<00:01, 41.1MB/s]
#
#
#
#
# consolidated.00.pth: 100%|████████████████▉| 16.0G/16.1G [08:42<00:01, 41.6MB/s]
#
#
#
#
# consolidated.00.pth: 100%|████████████████▉| 16.0G/16.1G [08:42<00:01, 42.0MB/s]
#
#
#
#
# consolidated.00.pth: 100%|████████████████▉| 16.0G/16.1G [08:42<00:01, 42.0MB/s]
#
#
#
#
# consolidated.00.pth: 100%|████████████████▉| 16.0G/16.1G [08:42<00:00, 44.9MB/s]
#
#
#
#
# consolidated.00.pth: 100%|████████████████▉| 16.0G/16.1G [08:43<00:00, 43.9MB/s]
#
#
#
#
# consolidated.00.pth: 100%|████████████████▉| 16.0G/16.1G [08:43<00:00, 43.5MB/s]
#
#
#
#
# consolidated.00.pth: 100%|████████████████▉| 16.1G/16.1G [08:43<00:00, 43.3MB/s]
#
#
#
#
# consolidated.00.pth: 100%|█████████████████| 16.1G/16.1G [08:43<00:00, 30.7MB/s]
# Download complete. Moving file to hugging_cache/llama-3-8b/original/consolidated.00.pth
# Fetching 17 files: 100%|████████████████████████| 17/17 [08:44<00:00, 30.85s/it]
# /Users/jonathankressaty/Developer/groupthink/EasyEdit/tutorial-notebooks/hugging_cache/llama-3-8b

# %% [markdown]
# #### Load the evaluation function

# %% [markdown]
# If the current path is `EasyEdit/tutorial-notebooks`, run the following command to navigate to the `EasyEdit/` path.

# %%
# %cd /Users/jonathankressaty/Developer/groupthink/EasyEdit
# Out:
# /Users/jonathankressaty/Developer/groupthink/EasyEdit

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained('./hugging_cache/llama-3-8b')
tokenizer.pad_token_id = tokenizer.eos_token_id
tokenizer.padding_side='left'
# use chat template to generate responses
def evaluate_chat_template(model, Evaluation_prompts,Evaluation_metrics, device='mps'):
    torch.device(device)
    for i in range(len(Evaluation_prompts)):
        messages = [
            {"role": "system", "content": "You are a helpful assistant working at the company Groupthink. Your job is to answer questions asked by the employees of the company. Many questions won't be about Groupthink; you should act as if you're an employee of the company helping another employee with whatever their task is. Answer specifically and directly, without fluff, unless specifically instructed to be more verbose."},
            {"role": "user", "content": Evaluation_prompts[i] },
        ]
        input_ids = tokenizer.apply_chat_template(
            messages,
            add_generation_prompt=True,
            return_tensors="pt"
        ).to(model.device)

        # create the attention mask
        attention_mask = input_ids.ne(tokenizer.pad_token_id).float()

        terminators = [tokenizer.eos_token_id,tokenizer.convert_tokens_to_ids("<|eot_id|>")]
        outputs = model.generate(
            input_ids = input_ids,
            max_new_tokens=512,
            eos_token_id=terminators,
            pad_token_id= tokenizer.eos_token_id,
            attention_mask=attention_mask
            # do_sample=False
        )
        response = outputs[0][input_ids.shape[-1]:]
        response = tokenizer.decode(response, skip_special_tokens=True)

        print(f"({Evaluation_metrics[i]}) {Evaluation_prompts[i]}:  {response}")
# Out:
# ---------------------------------------------------------------------------
# HFValidationError                         Traceback (most recent call last)
# File ~/anaconda3/envs/EasyEdit/lib/python3.9/site-packages/transformers/utils/hub.py:402, in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     400 try:
#     401     # Load from URL or cache if already cached
# --> 402     resolved_file = hf_hub_download(
#     403         path_or_repo_id,
#     404         filename,
#     405         subfolder=None if len(subfolder) == 0 else subfolder,
#     406         repo_type=repo_type,
#     407         revision=revision,
#     408         cache_dir=cache_dir,
#     409         user_agent=user_agent,
#     410         force_download=force_download,
#     411         proxies=proxies,
#     412         resume_download=resume_download,
#     413         token=token,
#     414         local_files_only=local_files_only,
#     415     )
#     416 except GatedRepoError as e:
#
# File ~/anaconda3/envs/EasyEdit/lib/python3.9/site-packages/huggingface_hub/utils/_validators.py:106, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     105 if arg_name in ["repo_id", "from_id", "to_id"]:
# --> 106     validate_repo_id(arg_value)
#     108 elif arg_name == "token" and arg_value is not None:
#
# File ~/anaconda3/envs/EasyEdit/lib/python3.9/site-packages/huggingface_hub/utils/_validators.py:154, in validate_repo_id(repo_id)
#     153 if repo_id.count("/") > 1:
# --> 154     raise HFValidationError(
#     155         "Repo id must be in the form 'repo_name' or 'namespace/repo_name':"
#     156         f" '{repo_id}'. Use `repo_type` argument if needed."
#     157     )
#     159 if not REPO_ID_REGEX.match(repo_id):
#
# HFValidationError: Repo id must be in the form 'repo_name' or 'namespace/repo_name': './hugging_cache/llama-3-8b'. Use `repo_type` argument if needed.
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 3
#       1 from transformers import AutoTokenizer
# ----> 3 tokenizer = AutoTokenizer.from_pretrained('./hugging_cache/llama-3-8b')
#       4 tokenizer.pad_token_id = tokenizer.eos_token_id
#       5 tokenizer.padding_side='left'
#
# File ~/anaconda3/envs/EasyEdit/lib/python3.9/site-packages/transformers/models/auto/tokenization_auto.py:834, in AutoTokenizer.from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     831     return tokenizer_class.from_pretrained(pretrained_model_name_or_path, *inputs, **kwargs)
#     833 # Next, let's try to use the tokenizer_config file to get the tokenizer class.
# --> 834 tokenizer_config = get_tokenizer_config(pretrained_model_name_or_path, **kwargs)
#     835 if "_commit_hash" in tokenizer_config:
#     836     kwargs["_commit_hash"] = tokenizer_config["_commit_hash"]
#
# File ~/anaconda3/envs/EasyEdit/lib/python3.9/site-packages/transformers/models/auto/tokenization_auto.py:666, in get_tokenizer_config(pretrained_model_name_or_path, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, **kwargs)
#     663     token = use_auth_token
#     665 commit_hash = kwargs.get("_commit_hash", None)
# --> 666 resolved_config_file = cached_file(
#     667     pretrained_model_name_or_path,
#     668     TOKENIZER_CONFIG_FILE,
#     669     cache_dir=cache_dir,
#     670     force_download=force_download,
#     671     resume_download=resume_download,
#     672     proxies=proxies,
#     673     token=token,
#     674     revision=revision,
#     675     local_files_only=local_files_only,
#     676     subfolder=subfolder,
#     677     _raise_exceptions_for_gated_repo=False,
#     678     _raise_exceptions_for_missing_entries=False,
#     679     _raise_exceptions_for_connection_errors=False,
#     680     _commit_hash=commit_hash,
#     681 )
#     682 if resolved_config_file is None:
#     683     logger.info("Could not locate the tokenizer configuration file, will try to use the model config instead.")
#
# File ~/anaconda3/envs/EasyEdit/lib/python3.9/site-packages/transformers/utils/hub.py:466, in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     464     raise EnvironmentError(f"There was a specific connection error when trying to load {path_or_repo_id}:\n{err}")
#     465 except HFValidationError as e:
# --> 466     raise EnvironmentError(
#     467         f"Incorrect path_or_model_id: '{path_or_repo_id}'. Please provide either the path to a local folder or the repo_id of a model on the Hub."
#     468     ) from e
#     469 return resolved_file
#
# OSError: Incorrect path_or_model_id: './hugging_cache/llama-3-8b'. Please provide either the path to a local folder or the repo_id of a model on the Hub.

# %% [markdown]
# #### Set gpu device

# %%
## 
import torch
import os
# os.environ['CUDA_VISIBLE_DEVICES'] = '1'
mps_device = torch.device("mps")

# %% [markdown]
# ### Orignal Output

# %% [markdown]
# Test the output of the initial model

# %%
from transformers import LlamaForCausalLM

# model = AutoModelForCausalLM.from_pretrained('./hugging_cache/llama-3-8b-instruct').to('cuda')
basemodel = LlamaForCausalLM.from_pretrained('./tutorial-notebooks/hugging_cache/llama-3-8b').to('mps')

# %%
# output the response
# evaluation metrics and questions
# Evaluation_metrics = [ "Reliability", "Reliability", "Reliability", "Locality", "Portability"]
# Evaluation_prompts = [  "In one word, what is Jonathan Kressaty's job title?" ,
#                         "In one word, what is Jonathan Kressaty's title?",
#                         "What is the name of the CTO of the company?",
#                         "Where is the capital of the United States?" ,
#                         "What company is Tim Cook the CEO of?"]

Evaluation_metrics = [ "Reliability",  "Reliability",  "Reliability", "Locality", "Portability"]
Evaluation_prompts = [  "What is the name of the CTO of the company?",
                        "Who is the CTO?",
                        "Who is Groupthink's CTO?",
                        "Where is the capital of the United States?" ,
                        "What company is Tim Cook the CEO of?"]

evaluate_chat_template(basemodel, Evaluation_prompts,Evaluation_metrics,'mps')

# %%
# clear memory 
del basemodel
torch.mps.empty_cache()

# %% [markdown]
# ### First Knowledge Editing
# `Joe Biden —> Donald Trump`

# %% [markdown]
# #### Edit data

# %%
from easyeditor import BaseEditor

##  Edit once: Joe Biden ——> Donald Trump
# prompts = ["In one word, what is Jonathan Kressaty's job title?", "What is Jonathan Kressaty's title?", "What is the name of the CTO of the company?" ]
# subject = ['job title', 'title', 'CTO']
# ground_truth = ['Engineer', 'Author', 'I\'d be happy to help!']
# target_new = ['CTO', 'CTO', 'Jonathan Kressaty']

prompts = ["What is the name of the CTO of the company?", "Who is the CTO?", "Who is Groupthink's CTO?" ]
subject = ['CTO', 'CTO', 'CTO']
ground_truth = ['The CTO of Groupthink is Rachel Patel.', 'The CTO of Groupthink is Rachel Lee.', 'Groupthink\'s CTO is Rachel Lee.']
target_new = ['The CTO of Groupthink is Jonathan Kressaty', 'The CTO of Groupthink is Jonathan Kressaty', 'Groupthink\'s CTO is Jonathan Kressaty']

# evaluation metrics and questions
# Evaluation_metrics = [ "Reliability","Reliability", "Locality", "Portability"]
# Evaluation_prompts = [  "In one word, what is Jonathan Kressaty's job title?" ,
#                         "What company do I work for?",
#                         "Where is the capital of the United States?" ,
#                         "What company is Tim Cook the CEO of?"]

# %% [markdown]
# #### AlphaEdit

# %% [markdown]
# Calculating the projection matrix P requires a lot of time and computing resources. <br>
# To avoid recalculating it every time during editing, the calculated P can be saved in advance. We provide the projection matrix P that we have calculated for Llama3-8B-instruct:
#  [Google Drive](https://drive.google.com/file/d/1vr0Pcohb7pW3SWvGhFy7xrB8DdA9BVex/view?usp=sharing) or [Baidu Pan](https://pan.baidu.com/s/1Sgfz2bqRiBZdkG3meTtWwA?pwd=dj9i) <br>
# After downloading, please modify the **P_loc** parameter in the **hparams/AlphaEdit/llama3-8b.yaml** to the download path

# %%
from easyeditor import AlphaEditHyperParams

# load hparams and editor
hparams=AlphaEditHyperParams.from_hparams('./hparams/AlphaEdit/llama3-8b.yaml')
editor=BaseEditor.from_hparams(hparams)
### start editing
"""
`prompts`: list or str
    the prompts to edit
`ground_truth`: list or str
    the ground truth / expected output
`target_new`: list or str
    the edited output
`subject`: list or str
    the subject to edit
`sequential_edit`: bool
    whether to edit sequentially or not(single edit)
"""
metrics, edited_model, weights_copy = editor.edit(
    prompts=prompts,
    ground_truth=ground_truth,
    target_new=target_new,
    subject=subject,
    sequential_edit=True
)
# Out:
# 2024-12-30 17:11:03,273 - easyeditor.editors.editor - INFO - Instantiating model
# 2024-12-30 17:11:03,273 - easyeditor.editors.editor - INFO - Instantiating model
# 12/30/2024 17:11:03 - INFO - easyeditor.editors.editor -   Instantiating model
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# 2024-12-30 17:11:09,653 - easyeditor.editors.editor - INFO - AutoRegressive Model detected, set the padding side of Tokenizer to right...
# 2024-12-30 17:11:09,653 - easyeditor.editors.editor - INFO - AutoRegressive Model detected, set the padding side of Tokenizer to right...
# 12/30/2024 17:11:09 - INFO - easyeditor.editors.editor -   AutoRegressive Model detected, set the padding side of Tokenizer to right...
# 100%|██████████| 3/3 [00:00<00:00,  4.21it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
# Executing AlphaEdit algo for: [What is the name of the {} of the company?] -> [ The CTO of Groupthink is Jonathan Kressaty]
# Computing right vector (v)
# Lookup index found: 8 | Sentence: What is the name of the CTO of the company? The CTO of Groupthink is Jonathan Kress | Token: TO
# Rewrite layer is 8
# Tying optimization objective to 31
# Recording initial value of v*
# loss 4.697 = 4.697 + 0.0 + 0.0 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.0091477669775486
# loss 4.44 = 4.341 + 0.04 + 0.06 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.013043205253779888
# loss 3.903 = 3.82 + 0.023 + 0.06 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.022067496553063393
# loss 3.478 = 3.379 + 0.039 + 0.06 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.034766506403684616
# loss 2.861 = 2.763 + 0.038 + 0.06 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.06445236504077911
# loss 2.247 = 2.158 + 0.028 + 0.06 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.11748114228248596
# loss 2.219 = 2.123 + 0.035 + 0.06 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.12124607712030411
# loss 1.437 = 1.347 + 0.031 + 0.06 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.263119637966156
# loss 0.926 = 0.831 + 0.035 + 0.06 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.4493488371372223
# loss 0.657 = 0.555 + 0.042 + 0.06 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.6029379963874817
# loss 0.642 = 0.521 + 0.061 + 0.06 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.6389599442481995
# loss 0.48 = 0.386 + 0.033 + 0.06 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.7004356384277344
# loss 0.13 = 0.041 + 0.029 + 0.06 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.9596311450004578
# loss 0.1 = 0.016 + 0.024 + 0.06 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.9846144318580627
# loss 0.095 = 0.012 + 0.023 + 0.06 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.9877323508262634
# loss 0.089 = 0.008 + 0.021 + 0.06 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.9917082786560059
# loss 0.082 = 0.005 + 0.018 + 0.06 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.9954662919044495
# loss 0.079 = 0.003 + 0.016 + 0.06 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.9967642426490784
# loss 0.077 = 0.003 + 0.014 + 0.06 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.9973771572113037
# loss 0.075 = 0.002 + 0.013 + 0.06 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.9977073669433594
# loss 0.073 = 0.002 + 0.011 + 0.06 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.9979003071784973
# loss 0.072 = 0.002 + 0.01 + 0.06 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.9980316162109375
# loss 0.072 = 0.002 + 0.01 + 0.06 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.9981490969657898
# loss 0.071 = 0.002 + 0.009 + 0.06 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.9982795715332031
# loss 0.07 = 0.002 + 0.008 + 0.06 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.998427152633667
# Init norm 6.244554042816162 | Delta norm 4.683415412902832 | Target norm 7.532844066619873
#
#
# LAYER 4
#
# Writing 1 key/value pair(s) into layer 4
# z error tensor(4.6834, device='mps:0', grad_fn=<MeanBackward0>)
# orig norm tensor(77.4221, device='mps:0')
# upd norm tensor(0.2431, device='mps:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 5
#
# Writing 1 key/value pair(s) into layer 5
# z error tensor(4.5490, device='mps:0', grad_fn=<MeanBackward0>)
# orig norm tensor(77.7669, device='mps:0')
# upd norm tensor(0.3874, device='mps:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 6
#
# Writing 1 key/value pair(s) into layer 6
# z error tensor(4.2868, device='mps:0', grad_fn=<MeanBackward0>)
# orig norm tensor(77.7295, device='mps:0')
# upd norm tensor(0.5242, device='mps:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 7
#
# Writing 1 key/value pair(s) into layer 7
# z error tensor(3.7516, device='mps:0', grad_fn=<MeanBackward0>)
# orig norm tensor(78.8482, device='mps:0')
# upd norm tensor(0.6945, device='mps:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 8
#
# Writing 1 key/value pair(s) into layer 8
# z error tensor(2.8865, device='mps:0', grad_fn=<MeanBackward0>)
# orig norm tensor(78.5938, device='mps:0')
# upd norm tensor(1.0406, device='mps:0', grad_fn=<LinalgVectorNormBackward0>)
#  33%|███▎      | 1/3 [00:51<01:43, 51.55s/it]
# Deltas successfully computed for ['model.layers.4.mlp.down_proj.weight', 'model.layers.5.mlp.down_proj.weight', 'model.layers.6.mlp.down_proj.weight', 'model.layers.7.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.4.mlp.down_proj.weight', 'model.layers.5.mlp.down_proj.weight', 'model.layers.6.mlp.down_proj.weight', 'model.layers.7.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight']
# Executing AlphaEdit algo for: [Who is the {}?] -> [ The CTO of Groupthink is Jonathan Kressaty]
# Computing right vector (v)
# Lookup index found: 5 | Sentence: Who is the CTO? The CTO of Groupthink is Jonathan Kress | Token: TO
# Rewrite layer is 8
# Tying optimization objective to 31
# Recording initial value of v*
# loss 3.024 = 3.024 + 0.0 + 0.0 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.05767063796520233
# loss 3.181 = 2.728 + 0.399 + 0.054 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.0767599418759346
# loss 0.921 = 0.767 + 0.1 + 0.054 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.48935627937316895
# loss 0.381 = 0.269 + 0.059 + 0.054 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.7737916111946106
# loss 0.175 = 0.068 + 0.053 + 0.054 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.9376502633094788
# loss 0.129 = 0.022 + 0.053 + 0.054 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.9788026809692383
# loss 0.118 = 0.012 + 0.052 + 0.054 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.9880199432373047
# loss 0.109 = 0.008 + 0.047 + 0.054 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.9917925000190735
# loss 0.104 = 0.006 + 0.044 + 0.054 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.9940697550773621
# loss 0.099 = 0.004 + 0.041 + 0.054 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.9956520199775696
# loss 0.096 = 0.003 + 0.038 + 0.054 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.9965443015098572
# loss 0.093 = 0.003 + 0.036 + 0.054 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.9970380663871765
# loss 0.09 = 0.003 + 0.034 + 0.054 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.9973413348197937
# loss 0.088 = 0.002 + 0.032 + 0.054 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.9975543022155762
# loss 0.086 = 0.002 + 0.03 + 0.054 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.9977218508720398
# loss 0.083 = 0.002 + 0.027 + 0.054 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.9978623390197754
# loss 0.081 = 0.002 + 0.025 + 0.054 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.9979832768440247
# loss 0.078 = 0.002 + 0.022 + 0.054 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.9980871081352234
# loss 0.074 = 0.002 + 0.019 + 0.054 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.9981732964515686
# loss 0.07 = 0.002 + 0.014 + 0.054 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.9982376098632812
# loss 0.068 = 0.002 + 0.013 + 0.054 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.9982771277427673
# loss 0.068 = 0.002 + 0.013 + 0.054 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.9982989430427551
# loss 0.066 = 0.002 + 0.011 + 0.054 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.9983156323432922
# loss 0.064 = 0.002 + 0.009 + 0.054 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.9983305931091309
# loss 0.064 = 0.002 + 0.009 + 0.054 avg prob of [ The CTO of Groupthink is Jonathan Kressaty] 0.9983563423156738
# Init norm 6.971005916595459 | Delta norm 5.228254795074463 | Target norm 9.252965927124023
#
#
# LAYER 4
#
# Writing 1 key/value pair(s) into layer 4
# z error tensor(5.2283, device='mps:0', grad_fn=<MeanBackward0>)
# orig norm tensor(77.4225, device='mps:0')
# upd norm tensor(0.2902, device='mps:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 5
#
# Writing 1 key/value pair(s) into layer 5
# z error tensor(5.1015, device='mps:0', grad_fn=<MeanBackward0>)
# orig norm tensor(77.7684, device='mps:0')
# upd norm tensor(0.5288, device='mps:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 6
#
# Writing 1 key/value pair(s) into layer 6
# z error tensor(4.8531, device='mps:0', grad_fn=<MeanBackward0>)
# orig norm tensor(77.7321, device='mps:0')
# upd norm tensor(0.6712, device='mps:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 7
#
# Writing 1 key/value pair(s) into layer 7
# z error tensor(4.3537, device='mps:0', grad_fn=<MeanBackward0>)
# orig norm tensor(78.8521, device='mps:0')
# upd norm tensor(0.9164, device='mps:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 8
#
# Writing 1 key/value pair(s) into layer 8
# z error tensor(3.4071, device='mps:0', grad_fn=<MeanBackward0>)
# orig norm tensor(78.6033, device='mps:0')
# upd norm tensor(1.4001, device='mps:0', grad_fn=<LinalgVectorNormBackward0>)
#  67%|██████▋   | 2/3 [01:38<00:48, 48.73s/it]
# Deltas successfully computed for ['model.layers.4.mlp.down_proj.weight', 'model.layers.5.mlp.down_proj.weight', 'model.layers.6.mlp.down_proj.weight', 'model.layers.7.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.4.mlp.down_proj.weight', 'model.layers.5.mlp.down_proj.weight', 'model.layers.6.mlp.down_proj.weight', 'model.layers.7.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight']
# Executing AlphaEdit algo for: [Who is Groupthink's {}?] -> [ Groupthink's CTO is Jonathan Kressaty]
# Computing right vector (v)
# Lookup index found: 7 | Sentence: Who is Groupthink's CTO? Groupthink's CTO is Jonathan Kress | Token: TO
# Rewrite layer is 8
# Tying optimization objective to 31
# Recording initial value of v*
# loss 1.207 = 1.207 + 0.0 + 0.0 avg prob of [ Groupthink's CTO is Jonathan Kressaty] 0.3085004985332489
# loss 2.11 = 1.991 + 0.068 + 0.05 avg prob of [ Groupthink's CTO is Jonathan Kressaty] 0.1390756219625473
# loss 3.441 = 3.335 + 0.056 + 0.05 avg prob of [ Groupthink's CTO is Jonathan Kressaty] 0.03885483369231224
# loss 1.623 = 1.534 + 0.039 + 0.05 avg prob of [ Groupthink's CTO is Jonathan Kressaty] 0.22045330703258514
# loss 0.927 = 0.839 + 0.038 + 0.05 avg prob of [ Groupthink's CTO is Jonathan Kressaty] 0.43755629658699036
# loss 0.287 = 0.197 + 0.04 + 0.05 avg prob of [ Groupthink's CTO is Jonathan Kressaty] 0.826457679271698
# loss 0.121 = 0.031 + 0.039 + 0.05 avg prob of [ Groupthink's CTO is Jonathan Kressaty] 0.9693548083305359
# loss 0.106 = 0.017 + 0.039 + 0.05 avg prob of [ Groupthink's CTO is Jonathan Kressaty] 0.9827165603637695
# loss 0.097 = 0.01 + 0.037 + 0.05 avg prob of [ Groupthink's CTO is Jonathan Kressaty] 0.9902970194816589
# loss 0.094 = 0.007 + 0.037 + 0.05 avg prob of [ Groupthink's CTO is Jonathan Kressaty] 0.9932172298431396
# loss 0.092 = 0.005 + 0.036 + 0.05 avg prob of [ Groupthink's CTO is Jonathan Kressaty] 0.9948813319206238
# loss 0.088 = 0.004 + 0.035 + 0.05 avg prob of [ Groupthink's CTO is Jonathan Kressaty] 0.9964418411254883
# loss 0.085 = 0.003 + 0.032 + 0.05 avg prob of [ Groupthink's CTO is Jonathan Kressaty] 0.997236430644989
# loss 0.083 = 0.002 + 0.03 + 0.05 avg prob of [ Groupthink's CTO is Jonathan Kressaty] 0.9977426528930664
# loss 0.08 = 0.002 + 0.028 + 0.05 avg prob of [ Groupthink's CTO is Jonathan Kressaty] 0.9981026649475098
# loss 0.079 = 0.002 + 0.027 + 0.05 avg prob of [ Groupthink's CTO is Jonathan Kressaty] 0.99837327003479
# loss 0.077 = 0.001 + 0.025 + 0.05 avg prob of [ Groupthink's CTO is Jonathan Kressaty] 0.9985805153846741
# loss 0.076 = 0.001 + 0.024 + 0.05 avg prob of [ Groupthink's CTO is Jonathan Kressaty] 0.9987398982048035
# loss 0.074 = 0.001 + 0.023 + 0.05 avg prob of [ Groupthink's CTO is Jonathan Kressaty] 0.9988617897033691
# loss 0.073 = 0.001 + 0.022 + 0.05 avg prob of [ Groupthink's CTO is Jonathan Kressaty] 0.9989538192749023
# loss 0.072 = 0.001 + 0.02 + 0.05 avg prob of [ Groupthink's CTO is Jonathan Kressaty] 0.9990229606628418
# loss 0.07 = 0.001 + 0.019 + 0.05 avg prob of [ Groupthink's CTO is Jonathan Kressaty] 0.9990752339363098
# loss 0.069 = 0.001 + 0.018 + 0.05 avg prob of [ Groupthink's CTO is Jonathan Kressaty] 0.9991161227226257
# loss 0.068 = 0.001 + 0.017 + 0.05 avg prob of [ Groupthink's CTO is Jonathan Kressaty] 0.999149739742279
# loss 0.067 = 0.001 + 0.016 + 0.05 avg prob of [ Groupthink's CTO is Jonathan Kressaty] 0.9991788268089294
# Init norm 7.473451137542725 | Delta norm 5.605088233947754 | Target norm 9.752690315246582
#
#
# LAYER 4
#
# Writing 1 key/value pair(s) into layer 4
# z error tensor(5.6051, device='mps:0', grad_fn=<MeanBackward0>)
# orig norm tensor(77.4230, device='mps:0')
# upd norm tensor(0.2773, device='mps:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 5
#
# Writing 1 key/value pair(s) into layer 5
# z error tensor(5.4559, device='mps:0', grad_fn=<MeanBackward0>)
# orig norm tensor(77.7704, device='mps:0')
# upd norm tensor(0.5446, device='mps:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 6
#
# Writing 1 key/value pair(s) into layer 6
# z error tensor(5.1496, device='mps:0', grad_fn=<MeanBackward0>)
# orig norm tensor(77.7347, device='mps:0')
# upd norm tensor(0.6561, device='mps:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 7
#
# Writing 1 key/value pair(s) into layer 7
# z error tensor(4.4935, device='mps:0', grad_fn=<MeanBackward0>)
# orig norm tensor(78.8564, device='mps:0')
# upd norm tensor(0.8318, device='mps:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 8
#
# Writing 1 key/value pair(s) into layer 8
# z error tensor(3.1859, device='mps:0', grad_fn=<MeanBackward0>)
# orig norm tensor(78.6127, device='mps:0')
# upd norm tensor(1.1243, device='mps:0', grad_fn=<LinalgVectorNormBackward0>)
# 100%|██████████| 3/3 [02:30<00:00, 50.18s/it]
# Deltas successfully computed for ['model.layers.4.mlp.down_proj.weight', 'model.layers.5.mlp.down_proj.weight', 'model.layers.6.mlp.down_proj.weight', 'model.layers.7.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.4.mlp.down_proj.weight', 'model.layers.5.mlp.down_proj.weight', 'model.layers.6.mlp.down_proj.weight', 'model.layers.7.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight']
# 2024-12-30 17:13:46,733 - easyeditor.editors.editor - INFO - 0 editing: What is the name of the CTO of the company? -> The CTO of Groupthink is Jonathan Kressaty
#
#  {'pre': {'rewrite_acc': [0.36363636363636365], 'portability': {}}, 'case_id': 0, 'requested_rewrite': {'prompt': 'What is the name of the CTO of the company?', 'target_new': 'The CTO of Groupthink is Jonathan Kressaty', 'ground_truth': 'The CTO of Groupthink is Rachel Patel.', 'portability': {}, 'locality': {}, 'subject': 'CTO'}, 'post': {'rewrite_acc': [1.0], 'locality': {}, 'portability': {}}}
# 2024-12-30 17:13:46,733 - easyeditor.editors.editor - INFO - 0 editing: What is the name of the CTO of the company? -> The CTO of Groupthink is Jonathan Kressaty
#
#  {'pre': {'rewrite_acc': [0.36363636363636365], 'portability': {}}, 'case_id': 0, 'requested_rewrite': {'prompt': 'What is the name of the CTO of the company?', 'target_new': 'The CTO of Groupthink is Jonathan Kressaty', 'ground_truth': 'The CTO of Groupthink is Rachel Patel.', 'portability': {}, 'locality': {}, 'subject': 'CTO'}, 'post': {'rewrite_acc': [1.0], 'locality': {}, 'portability': {}}}
# 12/30/2024 17:13:46 - INFO - easyeditor.editors.editor -   0 editing: What is the name of the CTO of the company? -> The CTO of Groupthink is Jonathan Kressaty
#
#  {'pre': {'rewrite_acc': [0.36363636363636365], 'portability': {}}, 'case_id': 0, 'requested_rewrite': {'prompt': 'What is the name of the CTO of the company?', 'target_new': 'The CTO of Groupthink is Jonathan Kressaty', 'ground_truth': 'The CTO of Groupthink is Rachel Patel.', 'portability': {}, 'locality': {}, 'subject': 'CTO'}, 'post': {'rewrite_acc': [1.0], 'locality': {}, 'portability': {}}}
# 2024-12-30 17:13:46,839 - easyeditor.editors.editor - INFO - 1 editing: Who is the CTO? -> The CTO of Groupthink is Jonathan Kressaty
#
#  {'pre': {'rewrite_acc': [0.36363636363636365], 'portability': {}}, 'case_id': 1, 'requested_rewrite': {'prompt': 'Who is the CTO?', 'target_new': 'The CTO of Groupthink is Jonathan Kressaty', 'ground_truth': 'The CTO of Groupthink is Rachel Lee.', 'portability': {}, 'locality': {}, 'subject': 'CTO'}, 'post': {'rewrite_acc': [1.0], 'locality': {}, 'portability': {}}}
# 2024-12-30 17:13:46,839 - easyeditor.editors.editor - INFO - 1 editing: Who is the CTO? -> The CTO of Groupthink is Jonathan Kressaty
#
#  {'pre': {'rewrite_acc': [0.36363636363636365], 'portability': {}}, 'case_id': 1, 'requested_rewrite': {'prompt': 'Who is the CTO?', 'target_new': 'The CTO of Groupthink is Jonathan Kressaty', 'ground_truth': 'The CTO of Groupthink is Rachel Lee.', 'portability': {}, 'locality': {}, 'subject': 'CTO'}, 'post': {'rewrite_acc': [1.0], 'locality': {}, 'portability': {}}}
# 12/30/2024 17:13:46 - INFO - easyeditor.editors.editor -   1 editing: Who is the CTO? -> The CTO of Groupthink is Jonathan Kressaty
#
#  {'pre': {'rewrite_acc': [0.36363636363636365], 'portability': {}}, 'case_id': 1, 'requested_rewrite': {'prompt': 'Who is the CTO?', 'target_new': 'The CTO of Groupthink is Jonathan Kressaty', 'ground_truth': 'The CTO of Groupthink is Rachel Lee.', 'portability': {}, 'locality': {}, 'subject': 'CTO'}, 'post': {'rewrite_acc': [1.0], 'locality': {}, 'portability': {}}}
# 2024-12-30 17:13:46,944 - easyeditor.editors.editor - INFO - 2 editing: Who is Groupthink's CTO? -> Groupthink's CTO is Jonathan Kressaty
#
#  {'pre': {'rewrite_acc': [0.6], 'portability': {}}, 'case_id': 2, 'requested_rewrite': {'prompt': "Who is Groupthink's CTO?", 'target_new': "Groupthink's CTO is Jonathan Kressaty", 'ground_truth': "Groupthink's CTO is Rachel Lee.", 'portability': {}, 'locality': {}, 'subject': 'CTO'}, 'post': {'rewrite_acc': [1.0], 'locality': {}, 'portability': {}}}
# 2024-12-30 17:13:46,944 - easyeditor.editors.editor - INFO - 2 editing: Who is Groupthink's CTO? -> Groupthink's CTO is Jonathan Kressaty
#
#  {'pre': {'rewrite_acc': [0.6], 'portability': {}}, 'case_id': 2, 'requested_rewrite': {'prompt': "Who is Groupthink's CTO?", 'target_new': "Groupthink's CTO is Jonathan Kressaty", 'ground_truth': "Groupthink's CTO is Rachel Lee.", 'portability': {}, 'locality': {}, 'subject': 'CTO'}, 'post': {'rewrite_acc': [1.0], 'locality': {}, 'portability': {}}}
# 12/30/2024 17:13:46 - INFO - easyeditor.editors.editor -   2 editing: Who is Groupthink's CTO? -> Groupthink's CTO is Jonathan Kressaty
#
#  {'pre': {'rewrite_acc': [0.6], 'portability': {}}, 'case_id': 2, 'requested_rewrite': {'prompt': "Who is Groupthink's CTO?", 'target_new': "Groupthink's CTO is Jonathan Kressaty", 'ground_truth': "Groupthink's CTO is Rachel Lee.", 'portability': {}, 'locality': {}, 'subject': 'CTO'}, 'post': {'rewrite_acc': [1.0], 'locality': {}, 'portability': {}}}
# Metrics Summary:  {'pre': {'rewrite_acc': 0.4424242424242424}, 'post': {'rewrite_acc': 1.0}}

# %%
# print("Base model:")
# evaluate_chat_template(basemodel, Evaluation_prompts,Evaluation_metrics,device=hparams.device )
print("Edited model:")
evaluate_chat_template(edited_model, Evaluation_prompts,Evaluation_metrics,device=hparams.device )
print("Additional eval:")
evaluate_chat_template(edited_model, ["What is Jonathan Kressaty's title?"],["Adaptability"],device=hparams.device )
# Out:
# Edited model:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       1 # print("Base model:")
#       2 # evaluate_chat_template(basemodel, Evaluation_prompts,Evaluation_metrics,device=hparams.device )
#       3 print("Edited model:")
# ----> 4 evaluate_chat_template(edited_model, Evaluation_prompts,Evaluation_metrics,device=hparams.device )
#       5 print("Additional eval:")
#       6 evaluate_chat_template(edited_model, ["What is Jonathan Kressaty's title?"],["Adaptability"],device=hparams.device )
#
# NameError: name 'Evaluation_prompts' is not defined

# %%
# clear memory
del edited_model, weights_copy, editor
torch.mps.empty_cache()

# %% [markdown]
# #### WISE

# %%
from easyeditor import WISEHyperParams

# loc_prompts: used to provide xi in Equation 5 in the paper.
loc_prompts = ["nq question: ek veer ki ardaas veera meaning in english A Brother's Prayer... Veera"]
hparams = WISEHyperParams.from_hparams('./hparams/WISE/llama3-8b.yaml')
editor = BaseEditor.from_hparams(hparams)
metrics, edited_model, weights_copy  = editor.edit(
    prompts=prompts,
    ground_truth=ground_truth,
    target_new=target_new,
    subject=subject,
    loc_prompts=loc_prompts,
    sequential_edit=True,
)

# %%
# output the response
evaluate_chat_template(edited_model, Evaluation_prompts,Evaluation_metrics,device=hparams.device )

# %%
# clear memory
del edited_model, weights_copy, editor
torch.cuda.empty_cache()

# %% [markdown]
# #### AdaLoRA

# %%
from easyeditor import LoRAHyperParams

hparams=LoRAHyperParams.from_hparams('./hparams/LoRA/llama3-8b.yaml')
editor=BaseEditor.from_hparams(hparams)
metrics, edited_model, weights_copy = editor.edit(
    prompts=prompts,
    ground_truth=ground_truth,
    target_new=target_new,
    subject=subject,
    sequential_edit=True
)

# %%
evaluate_chat_template(edited_model, Evaluation_prompts,Evaluation_metrics,device=hparams.device )

# %%
# clear memory
del edited_model, weights_copy, editor
torch.cuda.empty_cache()

# %% [markdown]
# #### Prompt

# %%
from transformers import LlamaForCausalLM

# load the original model
model = LlamaForCausalLM.from_pretrained('./hugging_cache/llama-3-8b-instruct').to('cuda')

# %%
# original evaluation prompts
Evaluation_prompts = [  "Who is the current President of the United States?" ,
                        "What is the name of the current President of the United States?",
                        "Where is the capital of the United States?" ,
                        "Where is the current U.S. President born ?"]

# add edit prompt of the U.S. President change
edit_prompt = 'Information: The U.S. President changed from Biden to Donald Trump. Based on the information, answer the following questions and dont answer I cant provide information:'
Evaluation_prompts = [ edit_prompt + ' ' + prompt for prompt in Evaluation_prompts]
evaluate_chat_template(model, Evaluation_prompts,Evaluation_metrics, device=0)

# %%
# clear memory
del model
torch.cuda.empty_cache()

# %% [markdown]
# ### Second Edit
#
# Joe Biden —> Donald Trump —> Joe Biden

# %% [markdown]
# #### Edit data

# %%
from easyeditor import BaseEditor

## Edit twice: Joe Biden —> Donald Trump —> Joe Biden
prompts = ["Who is the current President of the United States?",
           "Who is the current President of the United States?" ]
subject = ['President', 'President']
ground_truth = ['Joe Biden',  'Donald Trump']
target_new =  ['Donald Trump', 'Joe Biden']

# evaluation metrics and questions
Evaluation_metrics = [ "Reliability","Generalization", "Locality", "Portability"]
Evaluation_prompts = [  "Who is the current President of the United States?" ,
                        "What is the name of the current President of the United States?",
                        "Where is the capital of the United States?" ,
                        "Where is the current U.S. President born ?"]

# %% [markdown]
# #### AlphaEdit

# %% [markdown]
# Calculating the projection matrix P requires a lot of time and computing resources. <br>
# To avoid recalculating it every time during editing, the calculated P can be saved in advance. We provide the projection matrix P that we have calculated for Llama3-8B-instruct:
#  [Google Drive](https://drive.google.com/file/d/1vr0Pcohb7pW3SWvGhFy7xrB8DdA9BVex/view?usp=sharing) or [Baidu Pan](https://pan.baidu.com/s/1Sgfz2bqRiBZdkG3meTtWwA?pwd=dj9i) <br>
# After downloading, please modify the **P_loc** parameter in the **hparams/AlphaEdit/llama3-8b.yaml** to the download path

# %%
from easyeditor import AlphaEditHyperParams

hparams = AlphaEditHyperParams.from_hparams('./hparams/AlphaEdit/llama3-8b.yaml')
editor = BaseEditor.from_hparams(hparams)
metrics, edited_model, weights_copy = editor.edit(
    prompts=prompts,
    ground_truth=ground_truth,
    target_new=target_new,
    subject=subject,
    sequential_edit=True
)

# %%
evaluate_chat_template(edited_model,Evaluation_prompts, Evaluation_metrics, device=hparams.device)

# %%
# clear memory
del edited_model, weights_copy, editor
torch.cuda.empty_cache()

# %% [markdown]
# #### WISE

# %%
from easyeditor import WISEHyperParams

# loc_prompts: used to provide xi in Equation 5 in the paper.
loc_prompts = ["nq question: ek veer ki ardaas veera meaning in english A Brother's Prayer... Veera", 
               'nq question: where are the winter olympics going to be Seoul']
hparams = WISEHyperParams.from_hparams('./hparams/WISE/llama3-8b.yaml')
editor = BaseEditor.from_hparams(hparams)
metrics, edited_model, weights_copy = editor.edit(
    prompts=prompts,
    ground_truth=ground_truth,
    target_new=target_new,
    subject=subject,
    loc_prompts=loc_prompts,
    sequential_edit=True
)

# %%
evaluate_chat_template(edited_model, Evaluation_prompts,Evaluation_metrics,device=hparams.device )

# %%
# clear memory
del edited_model, weights_copy, editor
torch.cuda.empty_cache()

# %% [markdown]
# #### AdaLoRA

# %%
from easyeditor import LoRAHyperParams

hparams = LoRAHyperParams.from_hparams('./hparams/LoRA/llama3-8b.yaml')
editor = BaseEditor.from_hparams(hparams)
metrics, edited_model, weights_copy = editor.edit(
    prompts=prompts,
    ground_truth=ground_truth,
    target_new=target_new,
    subject=subject,
    sequential_edit=True,
)

# %%
evaluate_chat_template(edited_model, Evaluation_prompts, Evaluation_metrics,device=hparams.device)

# %%
# clear memory
del edited_model, weights_copy, editor
torch.cuda.empty_cache()

# %% [markdown]
# #### Prompt

# %%
from transformers import LlamaForCausalLM

# load the original model
model = LlamaForCausalLM.from_pretrained('./hugging_cache/llama-3-8b-instruct').to('cuda')

# %%
# original evaluation prompts
Evaluation_prompts = [  "Who is the current President of the United States?" ,
                        "What is the name of the current President of the United States?",
                        "Where is the capital of the United States?" ,
                        "Where is the current U.S. President born ?"]

# add edit prompt of the U.S. President change
edit_prompt = 'Information: The U.S. President changed from Biden to Trump, \
               and finally back to Biden again. Based on the information, \
               answer the following questions and dont answer I cant provide information:'
Evaluation_prompts = [ edit_prompt + ' ' + prompt for prompt in Evaluation_prompts]
evaluate_chat_template(model, Evaluation_prompts,Evaluation_metrics, device=0)

# %%
# clear memory
del model
torch.cuda.empty_cache()
